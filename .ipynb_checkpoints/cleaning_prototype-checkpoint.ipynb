# %%
import pickle
import pandas as pd
import re

# %%
ls
# Out:
# Data_Scraping_Prototype.ipynb  cleaning_prototype.ipynb
# README.md                      movie_info.pickle
# Untitled.ipynb                 movie_stubs.pickle

# %%
#load movie stub and info pickles
movie_info = pickle.load(open('movie_info.pickle', 'rb'))
movie_stubs = pickle.load(open('movie_stubs.pickle', 'rb'))

# %%
movie_info = pd.DataFrame(movie_info)
movie_info.set_index('title', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-9d1ec534c1ef> in <module>
#       1 movie_info = pd.DataFrame(movie_info)
# ----> 2 movie_info.set_index('title', inplace=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['title'] are in the columns"

# %%
movie_info.head()
# Out:
#                                                                 desc  \
# title
# Avengers: Endgame  After the devastating events of Avengers: Infi...
# The Lion King      After the murder of his father, a young lion p...
# Toy Story 4        When a new toy called "Forky" joins Woody and ...
# Frozen II          Anna, Elsa, Kristoff, Olaf and Sven leave Aren...
# Captain Marvel     Carol Danvers becomes one of the universe's mo...
#
#                                                                distr  \
# title
# Avengers: Endgame  Walt Disney Studios Motion PicturesSee full co...
# The Lion King      Walt Disney Studios Motion PicturesSee full co...
# Toy Story 4        Walt Disney Studios Motion PicturesSee full co...
# Frozen II          Walt Disney Studios Motion PicturesSee full co...
# Captain Marvel     Walt Disney Studios Motion PicturesSee full co...
#
#                                                    opening        budget  \
# title
# Avengers: Endgame  $357,115,0074,662\n            theaters  $356,000,000
# The Lion King      $191,770,7594,725\n            theaters  $260,000,000
# Toy Story 4        $120,908,0654,575\n            theaters  $200,000,000
# Frozen II          $130,263,3584,440\n            theaters  $150,000,000
# Captain Marvel     $153,433,4234,310\n            theaters  $160,000,000
#
#                     mpaa      runtime  \
# title
# Avengers: Endgame  PG-13   3 hr 1 min
# The Lion King         PG  1 hr 58 min
# Toy Story 4            G  1 hr 40 min
# Frozen II             PG  1 hr 43 min
# Captain Marvel     PG-13   2 hr 3 min
#
#                                                               genres  \
# title
# Avengers: Endgame                   Action, Adventure, Drama, Sci-Fi
# The Lion King           Adventure, Animation, Drama, Family, Musical
# Toy Story 4            Adventure, Animation, Comedy, Family, Fantasy
# Frozen II          Adventure, Animation, Comedy, Family, Fantasy,...
# Captain Marvel                             Action, Adventure, Sci-Fi
#
#                       gross_dom     gross_inter     gross_world
# title
# Avengers: Endgame  $858,373,000  $1,939,427,564  $2,797,800,564
# The Lion King      $543,638,043  $1,113,305,351  $1,656,943,394
# Toy Story 4        $434,038,008    $639,356,585  $1,073,394,593
# Frozen II          $477,373,578    $972,653,355  $1,450,026,933
# Captain Marvel     $426,829,839    $701,444,955  $1,128,274,794

# %%
movie_stubs.head()
# Out:
#                                                     link_stub       release  \
# Avengers: Endgame  /release/rl3059975681/?ref_=bo_yld_table_1  Apr 26, 2019
# The Lion King      /release/rl3321923073/?ref_=bo_yld_table_2  Jul 19, 2019
# Toy Story 4        /release/rl3798500865/?ref_=bo_yld_table_3  Jun 21, 2019
# Frozen II          /release/rl2424210945/?ref_=bo_yld_table_4  Nov 22, 2019
# Captain Marvel     /release/rl3009644033/?ref_=bo_yld_table_5   Mar 8, 2019
#
#                   theaters
# Avengers: Endgame     4662
# The Lion King         4802
# Toy Story 4           4575
# Frozen II             4440
# Captain Marvel        4310

# %%
movie_df = movie_stubs.merge(movie_info, left_index=True, right_index=True)

movie_df.drop_duplicates(inplace=True)

# %%
#quick check to see if I have enough budget data
movie_df.budget.isnull().value_counts()
# Out:
# False    2988
# True     1207
# Name: budget, dtype: int64

# %%
#removing trailing number of theaters from opening column

def clean_openings(opening):
    """
    Opening String grabbed both money and the row below.
    $357,115,0074,662\n theaters
    uses regex to remove opening theaters and the string
    input: (str)
    return : (str) $###,###,###
    """
    try:
        return re.search('^[$][0-9]{1,3},[0-9]{3},[0-9]{3}', opening).group()
    except:
        return None
    
movie_df['opening'] = movie_df.opening.map(clean_openings)

# %%
movie_df.filter(regex='Avengers', axis=0)
# Out:
#                                                           link_stub  \
# Avengers: Age of Ultron   /release/rl675644929/?ref_=bo_yld_table_3
# Avengers: Endgame        /release/rl3059975681/?ref_=bo_yld_table_1
# Avengers: Infinity War   /release/rl3043198465/?ref_=bo_yld_table_2
# The Avengers              /release/rl709199361/?ref_=bo_yld_table_1
#
#                               release theaters  \
# Avengers: Age of Ultron   May 1, 2015     4276
# Avengers: Endgame        Apr 26, 2019     4662
# Avengers: Infinity War   Apr 27, 2018     4474
# The Avengers              May 4, 2012     4349
#
#                                                                       desc  \
# Avengers: Age of Ultron  When Tony Stark and Bruce Banner try to jump-s...
# Avengers: Endgame        After the devastating events of Avengers: Infi...
# Avengers: Infinity War   The Avengers and their allies must be willing ...
# The Avengers             Earth's mightiest heroes must come together an...
#
#                                                                      distr  \
# Avengers: Age of Ultron  Walt Disney Studios Motion PicturesSee full co...
# Avengers: Endgame        Walt Disney Studios Motion PicturesSee full co...
# Avengers: Infinity War   Walt Disney Studios Motion PicturesSee full co...
# The Avengers             Walt Disney Studios Motion PicturesSee full co...
#
#                               opening        budget   mpaa      runtime  \
# Avengers: Age of Ultron  $191,271,109  $250,000,000  PG-13  2 hr 21 min
# Avengers: Endgame        $357,115,007  $356,000,000  PG-13   3 hr 1 min
# Avengers: Infinity War   $257,698,183          None  PG-13  2 hr 29 min
# The Avengers             $207,438,708  $220,000,000  PG-13  2 hr 23 min
#
#                                                    genres     gross_dom  \
# Avengers: Age of Ultron         Action, Adventure, Sci-Fi  $459,005,868
# Avengers: Endgame        Action, Adventure, Drama, Sci-Fi  $858,373,000
# Avengers: Infinity War          Action, Adventure, Sci-Fi  $678,815,482
# The Avengers                    Action, Adventure, Sci-Fi  $623,357,910
#
#                             gross_inter     gross_world
# Avengers: Age of Ultron    $943,800,000  $1,402,805,868
# Avengers: Endgame        $1,939,427,564  $2,797,800,564
# Avengers: Infinity War   $1,369,544,272  $2,048,359,754
# The Avengers               $895,455,078  $1,518,812,988

# %%
def clean_money(money):
    """
    Convert Money from string to number. 
    
    input : (str) 
    return : (int)
    """
    try:
        return ''.join(money.split(','))[1:]
    except:
        return None

# %%
movie_df.opening = movie_df.opening.map(clean_money)
movie_df.budget = movie_df.budget.map(clean_money)
movie_df.gross_dom = movie_df.gross_dom.map(clean_money)
movie_df.gross_inter = movie_df.gross_inter.map(clean_money)
movie_df.gross_world = movie_df.gross_world.map(clean_money)

# %%
movie_df.head()
# Out:
#                                                        link_stub  \
# 10 Cloverfield Lane  /release/rl1329956353/?ref_=bo_yld_table_44
# 10,000 BC             /release/rl977372673/?ref_=bo_yld_table_26
# 102 Dalmatians       /release/rl927041025/?ref_=bo_yld_table_137
# 102 Dalmatians        /release/rl927041025/?ref_=bo_yld_table_44
# 12 Rounds            /release/rl440501761/?ref_=bo_yld_table_147
#
#                           release theaters  \
# 10 Cloverfield Lane  Mar 11, 2016     3427
# 10,000 BC             Mar 7, 2008     3454
# 102 Dalmatians       Nov 22, 2001     2704
# 102 Dalmatians       Nov 22, 2000     2704
# 12 Rounds            Mar 27, 2009     2331
#
#                                                                   desc  \
# 10 Cloverfield Lane  After getting in a car accident, a woman is he...
# 10,000 BC            In the prehistoric past, D'Leh is a mammoth hu...
# 102 Dalmatians       Cruella DeVil gets out of prison and goes afte...
# 102 Dalmatians       Cruella DeVil gets out of prison and goes afte...
# 12 Rounds            Detective Danny Fisher discovers his girlfrien...
#
#                                                                  distr  \
# 10 Cloverfield Lane  Paramount PicturesSee full company information...
# 10,000 BC                 Warner Bros.See full company information\n\n
# 102 Dalmatians       Walt Disney Studios Motion PicturesSee full co...
# 102 Dalmatians       Walt Disney Studios Motion PicturesSee full co...
# 12 Rounds            Twentieth Century FoxSee full company informat...
#
#                       opening     budget   mpaa      runtime  \
# 10 Cloverfield Lane  24727437       None  PG-13  1 hr 43 min
# 10,000 BC            35867488  105000000  PG-13  1 hr 49 min
# 102 Dalmatians       19883351   85000000   None  1 hr 40 min
# 102 Dalmatians       19883351   85000000   None  1 hr 40 min
# 12 Rounds             5329240       None  PG-13  1 hr 48 min
#
#                                                                genres  \
# 10 Cloverfield Lane  Action, Drama, Horror, Mystery, Sci-Fi, Thriller
# 10,000 BC                  Action, Adventure, Drama, Fantasy, History
# 102 Dalmatians                              Adventure, Comedy, Family
# 102 Dalmatians                              Adventure, Comedy, Family
# 12 Rounds                                     Action, Crime, Thriller
#
#                     gross_dom gross_inter gross_world
# 10 Cloverfield Lane  72082998    38134000   110216998
# 10,000 BC            94784201   175000000   269784201
# 102 Dalmatians       66957026   116654745   183611771
# 102 Dalmatians       66957026   116654745   183611771
# 12 Rounds            12234694     5045632    17280326

# %%
with open('clean_movie_df.pickle', 'wb') as to_write:
    pickle.dump(movie_df, to_write)

# %%
ls
# Out:
# Data_Scraping_Prototype.ipynb  cleaning_prototype.ipynb
# README.md                      movie_info.pickle
# Untitled.ipynb                 movie_stubs.pickle
# clean_movie_df.pickle

# %% [markdown]
# September 30, 2020

# %%
movie_df.head()
# Out:
#                                                        link_stub  \
# 10 Cloverfield Lane  /release/rl1329956353/?ref_=bo_yld_table_44
# 10,000 BC             /release/rl977372673/?ref_=bo_yld_table_26
# 102 Dalmatians       /release/rl927041025/?ref_=bo_yld_table_137
# 102 Dalmatians        /release/rl927041025/?ref_=bo_yld_table_44
# 12 Rounds            /release/rl440501761/?ref_=bo_yld_table_147
#
#                           release theaters  \
# 10 Cloverfield Lane  Mar 11, 2016     3427
# 10,000 BC             Mar 7, 2008     3454
# 102 Dalmatians       Nov 22, 2001     2704
# 102 Dalmatians       Nov 22, 2000     2704
# 12 Rounds            Mar 27, 2009     2331
#
#                                                                   desc  \
# 10 Cloverfield Lane  After getting in a car accident, a woman is he...
# 10,000 BC            In the prehistoric past, D'Leh is a mammoth hu...
# 102 Dalmatians       Cruella DeVil gets out of prison and goes afte...
# 102 Dalmatians       Cruella DeVil gets out of prison and goes afte...
# 12 Rounds            Detective Danny Fisher discovers his girlfrien...
#
#                                                                  distr  \
# 10 Cloverfield Lane  Paramount PicturesSee full company information...
# 10,000 BC                 Warner Bros.See full company information\n\n
# 102 Dalmatians       Walt Disney Studios Motion PicturesSee full co...
# 102 Dalmatians       Walt Disney Studios Motion PicturesSee full co...
# 12 Rounds            Twentieth Century FoxSee full company informat...
#
#                       opening     budget   mpaa      runtime  \
# 10 Cloverfield Lane  24727437       None  PG-13  1 hr 43 min
# 10,000 BC            35867488  105000000  PG-13  1 hr 49 min
# 102 Dalmatians       19883351   85000000   None  1 hr 40 min
# 102 Dalmatians       19883351   85000000   None  1 hr 40 min
# 12 Rounds             5329240       None  PG-13  1 hr 48 min
#
#                                                                genres  \
# 10 Cloverfield Lane  Action, Drama, Horror, Mystery, Sci-Fi, Thriller
# 10,000 BC                  Action, Adventure, Drama, Fantasy, History
# 102 Dalmatians                              Adventure, Comedy, Family
# 102 Dalmatians                              Adventure, Comedy, Family
# 12 Rounds                                     Action, Crime, Thriller
#
#                     gross_dom gross_inter gross_world
# 10 Cloverfield Lane  72082998    38134000   110216998
# 10,000 BC            94784201   175000000   269784201
# 102 Dalmatians       66957026   116654745   183611771
# 102 Dalmatians       66957026   116654745   183611771
# 12 Rounds            12234694     5045632    17280326

# %%
#Remove noise from distributor column
def clean_distr(x):
    try:
        return x[:re.search('See full company', x).start()]
    except:
        return None

movie_df.distr = movie_df.distr.apply(clean_distr)

# %%
#convert runtime to numbers of mins 
def runtime_mins(runt):
    """
    Converts runtime to total minutes 
    args:
    runt (str) : 1 hr 43 min
    return:
    n (int) : number of minutes
    """
    n = 0
    try:
        if runt == '2 hr':
            return 120
        elif runt == '45 min':
            return 45
        elif runt == '1 hr':
            return 60
        elif runt == '48 min':
            return 48
        elif runt == '3 hr':
            return 180
        elif runt == '30 min':
            return 30
        
        hr, mins = int(runt.split()[0]), int(runt.split()[2])
        n = hr*60+mins

    except:
        return None
    
    return n

movie_df.runtime = movie_df.runtime.apply(runtime_mins)

# %%
with open('clean_movie_df.pickle', 'wb') as to_write:
    pickle.dump(movie_df, to_write)

# %%
movie_df = pickle.load(open('clean_movie_df.pickle', 'rb'))

# %%
movie_df.runtime.isnull().value_counts()
# Out:
# False    4191
# True        4
# Name: runtime, dtype: int64

# %%
movie_df.isnull().sum()
# Out:
# link_stub      0
# release        0
# theaters       0
# desc           0
# distr          0
# opening        0
# budget         0
# mpaa           0
# runtime        0
# genres         0
# gross_dom      0
# gross_inter    0
# gross_world    0
# dtype: int64

# %%
movie_df.dropna(axis=0, inplace=True)

# %%
movie_df
# Out:
#                                                                link_stub  \
# 10,000 BC                     /release/rl977372673/?ref_=bo_yld_table_26
# 13 Going on 30                /release/rl524387841/?ref_=bo_yld_table_57
# 13 Hours                     /release/rl2105378305/?ref_=bo_yld_table_62
# 15 Minutes                    /release/rl188843521/?ref_=bo_yld_table_92
# 2 Fast 2 Furious             /release/rl1178699265/?ref_=bo_yld_table_15
# ...                                                                  ...
# xXx                         /release/rl1450870273/?ref_=bo_yld_table_481
# xXx                          /release/rl1450870273/?ref_=bo_yld_table_15
# xXx: Return of Xander Cage   /release/rl1904182785/?ref_=bo_yld_table_63
# Æon Flux                    /release/rl1212188161/?ref_=bo_yld_table_270
# Æon Flux                    /release/rl1212188161/?ref_=bo_yld_table_102
#
#                                  release theaters  \
# 10,000 BC                    Mar 7, 2008     3454
# 13 Going on 30              Apr 23, 2004     3453
# 13 Hours                    Jan 15, 2016     2917
# 15 Minutes                   Mar 9, 2001     2337
# 2 Fast 2 Furious             Jun 6, 2003     3418
# ...                                  ...      ...
# xXx                          Aug 9, 2003     3536
# xXx                          Aug 9, 2002     3536
# xXx: Return of Xander Cage  Jan 20, 2017     3651
# Æon Flux                     Dec 2, 2006     2608
# Æon Flux                     Dec 2, 2005     2608
#
#                                                                          desc  \
# 10,000 BC                   In the prehistoric past, D'Leh is a mammoth hu...
# 13 Going on 30              A girl makes a wish on her thirteenth birthday...
# 13 Hours                    During an attack on a U.S. compound in Libya, ...
# 15 Minutes                  A homicide detective and a fire marshal must s...
# 2 Fast 2 Furious            Former cop Brian O'Conner is called upon to bu...
# ...                                                                       ...
# xXx                         An extreme sports athlete, Xander Cage, is rec...
# xXx                         An extreme sports athlete, Xander Cage, is rec...
# xXx: Return of Xander Cage  Xander Cage is left for dead after an incident...
# Æon Flux                    Aeon Flux is a mysterious assassin working for...
# Æon Flux                    Aeon Flux is a mysterious assassin working for...
#
#                                          distr   opening     budget   mpaa  \
# 10,000 BC                         Warner Bros.  35867488  105000000  PG-13
# 13 Going on 30              Revolution Studios  21054283   37000000  PG-13
# 13 Hours                    Paramount Pictures  16194738   50000000      R
# 15 Minutes                     New Line Cinema  10523154   60000000      R
# 2 Fast 2 Furious            Universal Pictures  50472480   76000000  PG-13
# ...                                        ...       ...        ...    ...
# xXx                         Revolution Studios  44506103   70000000  PG-13
# xXx                         Revolution Studios  44506103   70000000  PG-13
# xXx: Return of Xander Cage  Paramount Pictures  20130142   85000000  PG-13
# Æon Flux                    Paramount Pictures  12661112   62000000  PG-13
# Æon Flux                    Paramount Pictures  12661112   62000000  PG-13
#
#                             runtime  \
# 10,000 BC                     109.0
# 13 Going on 30                 98.0
# 13 Hours                      144.0
# 15 Minutes                    120.0
# 2 Fast 2 Furious              107.0
# ...                             ...
# xXx                           124.0
# xXx                           124.0
# xXx: Return of Xander Cage    107.0
# Æon Flux                       93.0
# Æon Flux                       93.0
#
#                                                                 genres  \
# 10,000 BC                   Action, Adventure, Drama, Fantasy, History
# 13 Going on 30                                Comedy, Fantasy, Romance
# 13 Hours                                   Action, Drama, History, War
# 15 Minutes                              Action, Crime, Drama, Thriller
# 2 Fast 2 Furious                               Action, Crime, Thriller
# ...                                                                ...
# xXx                                        Action, Adventure, Thriller
# xXx                                        Action, Adventure, Thriller
# xXx: Return of Xander Cage                 Action, Adventure, Thriller
# Æon Flux                           Action, Adventure, Sci-Fi, Thriller
# Æon Flux                           Action, Adventure, Sci-Fi, Thriller
#
#                             gross_dom gross_inter gross_world
# 10,000 BC                    94784201   175000000   269784201
# 13 Going on 30               57231747    39223950    96455697
# 13 Hours                     52853219    16558151    69411370
# 15 Minutes                   24403552    31956428    56359980
# 2 Fast 2 Furious            127154901   109195760   236350661
# ...                               ...         ...         ...
# xXx                         142109382   135339000   277448382
# xXx                         142109382   135339000   277448382
# xXx: Return of Xander Cage   44898413   301219864   346118277
# Æon Flux                     25874337    27447336    53321673
# Æon Flux                     25874337    27447336    53321673
#
# [2492 rows x 13 columns]

# %%
crew_list = pickle.load(open('cast_info.pickle', 'rb'))

# %%
crew_df.drop(columns=['Nov 9, 2001', 'Oct 9, 2015'], inplace=True)

# %%
crew_list = pickle.load(open('cast_info.pickle', 'rb'))
crew_df = pd.DataFrame(crew_list)

crew_df.drop(columns=['Nov 9, 2001', 'Oct 9, 2015'], inplace=True)
crew_df.title = crew_df.title.apply(lambda x : x[:re.search('[(][0-9]{4}[)]', x).start()].rstrip())
crew_df.set_index('title', inplace=True)

# %%
movie_df = movie_df.merge(crew_df, left_index=True, right_index=True)

# %%
ls
# Out:
# Data_Scraping_Prototype.ipynb           clean_movie_df.pickle
# Data_Scraping_Prototype_Selenium.ipynb  cleaning_prototype.ipynb
# Feature Engineering.ipynb               geckodriver.log
# README.md                               movie_info.pickle
# cast_info.pickle                        movie_stubs.pickle
# cast_info_list1500_to_end.pickle        processed_movie_df.pickle
# cast_info_list_start_to_1500.pickle     usholidays.csv

# %%
with open('clean_movie_df.pickle', 'wb') as to_write:
    pickle.dump(movie_df, to_write)
