# %%
import pickle
import pandas as pd
import numpy as np
import datetime as dt

# %%
movie_df = pickle.load(open('clean_movie_df.pickle', 'rb'))

# %%
#read holidays csv
holidays = pd.read_csv('usholidays.csv')

#convert all dates to datetime/timestamp
movie_df.release = pd.to_datetime(movie_df.release)
holidays.loc[:,'Date'] = pd.to_datetime(holidays.Date)

#filter out holiday dates before the year 2000
holidays = holidays[holidays.Date >= dt.datetime(2000,1,1)].Date

def find_closest_holiday(date):
    """
    Finds the days to the nearest US Federal Holiday
    args:
    date (timestamp)
    returns:
    nearest_hol (int) days to the nearest holiday
    """
    nearest_hol = 365
    for hol in holidays:
        d = abs((hol - date).days)
        if d < nearest_hol:
            nearest_hol = d
    return nearest_hol

movie_df['holiday_distance'] = movie_df.release.map(find_closest_holiday)

# %%
movie_df.describe()
# Out:
#            runtime  holiday_distance
# count  2527.000000       2527.000000
# mean    109.890384         12.677879
# std      18.538448         11.398243
# min      68.000000          0.000000
# 25%      96.000000          4.000000
# 50%     107.000000         10.000000
# 75%     120.000000         17.000000
# max     219.000000         52.000000

# %%
def dummies():
    #Get dummies from Genres
    movie_df = movie_df.merge(movie_df.genres.str.get_dummies(sep=','), left_index=True, right_index=True, );

    #Get dummies from movie distributor
    movie_df = movie_df.merge(pd.get_dummies(movie_df.distr), left_index=True, right_index=True);

# %%
with open('processed_movie_df.pickle', 'wb') as to_write:
    pickle.dump(movie_df, to_write)

# %%
movie_df
# Out:
#                                                                link_stub  \
# 10,000 BC                     /release/rl977372673/?ref_=bo_yld_table_26
# 13 Going on 30                /release/rl524387841/?ref_=bo_yld_table_57
# 13 Hours                     /release/rl2105378305/?ref_=bo_yld_table_62
# 15 Minutes                    /release/rl188843521/?ref_=bo_yld_table_92
# 2 Fast 2 Furious             /release/rl1178699265/?ref_=bo_yld_table_15
# ...                                                                  ...
# xXx                         /release/rl1450870273/?ref_=bo_yld_table_481
# xXx                          /release/rl1450870273/?ref_=bo_yld_table_15
# xXx: Return of Xander Cage   /release/rl1904182785/?ref_=bo_yld_table_63
# Æon Flux                    /release/rl1212188161/?ref_=bo_yld_table_270
# Æon Flux                    /release/rl1212188161/?ref_=bo_yld_table_102
#
#                               release theaters  \
# 10,000 BC                  2008-03-07     3454
# 13 Going on 30             2004-04-23     3453
# 13 Hours                   2016-01-15     2917
# 15 Minutes                 2001-03-09     2337
# 2 Fast 2 Furious           2003-06-06     3418
# ...                               ...      ...
# xXx                        2003-08-09     3536
# xXx                        2002-08-09     3536
# xXx: Return of Xander Cage 2017-01-20     3651
# Æon Flux                   2006-12-02     2608
# Æon Flux                   2005-12-02     2608
#
#                                                                          desc  \
# 10,000 BC                   In the prehistoric past, D'Leh is a mammoth hu...
# 13 Going on 30              A girl makes a wish on her thirteenth birthday...
# 13 Hours                    During an attack on a U.S. compound in Libya, ...
# 15 Minutes                  A homicide detective and a fire marshal must s...
# 2 Fast 2 Furious            Former cop Brian O'Conner is called upon to bu...
# ...                                                                       ...
# xXx                         An extreme sports athlete, Xander Cage, is rec...
# xXx                         An extreme sports athlete, Xander Cage, is rec...
# xXx: Return of Xander Cage  Xander Cage is left for dead after an incident...
# Æon Flux                    Aeon Flux is a mysterious assassin working for...
# Æon Flux                    Aeon Flux is a mysterious assassin working for...
#
#                                          distr   opening     budget   mpaa  \
# 10,000 BC                         Warner Bros.  35867488  105000000  PG-13
# 13 Going on 30              Revolution Studios  21054283   37000000  PG-13
# 13 Hours                    Paramount Pictures  16194738   50000000      R
# 15 Minutes                     New Line Cinema  10523154   60000000      R
# 2 Fast 2 Furious            Universal Pictures  50472480   76000000  PG-13
# ...                                        ...       ...        ...    ...
# xXx                         Revolution Studios  44506103   70000000  PG-13
# xXx                         Revolution Studios  44506103   70000000  PG-13
# xXx: Return of Xander Cage  Paramount Pictures  20130142   85000000  PG-13
# Æon Flux                    Paramount Pictures  12661112   62000000  PG-13
# Æon Flux                    Paramount Pictures  12661112   62000000  PG-13
#
#                             runtime  \
# 10,000 BC                     109.0
# 13 Going on 30                 98.0
# 13 Hours                      144.0
# 15 Minutes                    120.0
# 2 Fast 2 Furious              107.0
# ...                             ...
# xXx                           124.0
# xXx                           124.0
# xXx: Return of Xander Cage    107.0
# Æon Flux                       93.0
# Æon Flux                       93.0
#
#                                                                 genres  ...  \
# 10,000 BC                   Action, Adventure, Drama, Fantasy, History  ...
# 13 Going on 30                                Comedy, Fantasy, Romance  ...
# 13 Hours                                   Action, Drama, History, War  ...
# 15 Minutes                              Action, Crime, Drama, Thriller  ...
# 2 Fast 2 Furious                               Action, Crime, Thriller  ...
# ...                                                                ...  ...
# xXx                                        Action, Adventure, Thriller  ...
# xXx                                        Action, Adventure, Thriller  ...
# xXx: Return of Xander Cage                 Action, Adventure, Thriller  ...
# Æon Flux                           Action, Adventure, Sci-Fi, Thriller  ...
# Æon Flux                           Action, Adventure, Sci-Fi, Thriller  ...
#
#                            gross_world         Director  \
# 10,000 BC                    269784201  Roland Emmerich
# 13 Going on 30                96455697      Gary Winick
# 13 Hours                      69411370      Michael Bay
# 15 Minutes                    56359980    John Herzfeld
# 2 Fast 2 Furious             236350661   John Singleton
# ...                                ...              ...
# xXx                          277448382        Rob Cohen
# xXx                          277448382        Rob Cohen
# xXx: Return of Xander Cage   346118277      D.J. Caruso
# Æon Flux                      53321673     Karyn Kusama
# Æon Flux                      53321673     Karyn Kusama
#
#                                                                        Writer  \
# 10,000 BC                                      Roland Emmerich, Harald Kloser
# 13 Going on 30                                    Josh Goldsmith, Cathy Yuspa
# 13 Hours                                        Chuck Hogan, Mitchell Zuckoff
# 15 Minutes                                                      John Herzfeld
# 2 Fast 2 Furious            Gary Scott Thompson, Michael Brandt, Derek Haa...
# ...                                                                       ...
# xXx                                                               Rich Wilkes
# xXx                                                               Rich Wilkes
# xXx: Return of Xander Cage                      Rich Wilkes, F. Scott Frazier
# Æon Flux                                 Phil Hay, Matt Manfredi, Peter Chung
# Æon Flux                                 Phil Hay, Matt Manfredi, Peter Chung
#
#                                                                      Producer  \
# 10,000 BC                         Roland Emmerich, Mark Gordon, Michael Wimer
# 13 Going on 30                        Susan Arnold, Gina Matthews, Donna Roth
# 13 Hours                                             Michael Bay, Erwin Stoff
# 15 Minutes                  Keith Addis, David Blocker, John Herzfeld, Nic...
# 2 Fast 2 Furious                                               Neal H. Moritz
# ...                                                                       ...
# xXx                                                            Neal H. Moritz
# xXx                                                            Neal H. Moritz
# xXx: Return of Xander Cage  Vin Diesel, Jeff Kirschenbaum, Joe Roth, Saman...
# Æon Flux                    David Gale, Gregory Goodman, Martha Griffin, G...
# Æon Flux                    David Gale, Gregory Goodman, Martha Griffin, G...
#
#                                                         Composer  \
# 10,000 BC                           Harald Kloser, Thomas Wanker
# 13 Going on 30                                  Theodore Shapiro
# 13 Hours                                             Lorne Balfe
# 15 Minutes                  Anthony Marinelli, J. Peter Robinson
# 2 Fast 2 Furious                                    David Arnold
# ...                                                          ...
# xXx                                                Randy Edelman
# xXx                                                Randy Edelman
# xXx: Return of Xander Cage          Robert Lydecker, Brian Tyler
# Æon Flux                                           Graeme Revell
# Æon Flux                                           Graeme Revell
#
#                                 Cinematographer  \
# 10,000 BC                          Ueli Steiger
# 13 Going on 30                      Don Burgess
# 13 Hours                             Dion Beebe
# 15 Minutes                  Jean-Yves Escoffier
# 2 Fast 2 Furious            Matthew F. Leonetti
# ...                                         ...
# xXx                                 Dean Semler
# xXx                                 Dean Semler
# xXx: Return of Xander Cage    Russell Carpenter
# Æon Flux                        Stuart Dryburgh
# Æon Flux                        Stuart Dryburgh
#
#                                                                     Editor  \
# 10,000 BC                                                 Alexander Berner
# 13 Going on 30                                            Susan Littenberg
# 13 Hours                    Michael McCusker, Pietro Scalia, Calvin Wimmer
# 15 Minutes                                                    Steven Cohen
# 2 Fast 2 Furious                                Bruce Cannon, Dallas Puett
# ...                                                                    ...
# xXx                               Chris Lebenzon, Joel Negron, Paul Rubell
# xXx                               Chris Lebenzon, Joel Negron, Paul Rubell
# xXx: Return of Xander Cage                       Vince Filippone, Jim Page
# Æon Flux                           Jeff Gullo, Peter Honess, Plummy Tucker
# Æon Flux                           Jeff Gullo, Peter Honess, Plummy Tucker
#
#                            Production Designer  \
# 10,000 BC                   Jean-Vincent Puzos
# 13 Going on 30                  Garreth Stover
# 13 Hours                      Jeffrey Beecroft
# 15 Minutes                         Mayne Berke
# 2 Fast 2 Furious             Keith Brian Burns
# ...                                        ...
# xXx                              Gavin Bocquet
# xXx                              Gavin Bocquet
# xXx: Return of Xander Cage      Jon Billington
# Æon Flux                       Andrew McAlpine
# Æon Flux                       Andrew McAlpine
#
#                                                                        Actors  \
# 10,000 BC                   Camilla Belle, Steven Strait, Marco Khan, Clif...
# 13 Going on 30              Jennifer Garner, Mark Ruffalo, Judy Greer, And...
# 13 Hours                    John Krasinski, Pablo Schreiber, James Badge D...
# 15 Minutes                  Robert De Niro, Edward Burns, Kelsey Grammer, ...
# 2 Fast 2 Furious            Paul Walker, Tyrese Gibson, Cole Hauser, Eva M...
# ...                                                                       ...
# xXx                         Vin Diesel, Asia Argento, Marton Csokas, Samue...
# xXx                         Vin Diesel, Asia Argento, Marton Csokas, Samue...
# xXx: Return of Xander Cage  Vin Diesel, Donnie Yen, Deepika Padukone, Kris Wu
# Æon Flux                    Charlize Theron, Frances McDormand, Sophie Oko...
# Æon Flux                    Charlize Theron, Frances McDormand, Sophie Oko...
#
#                            holiday_distance
# 10,000 BC                                18
# 13 Going on 30                           38
# 13 Hours                                  3
# 15 Minutes                               18
# 2 Fast 2 Furious                         11
# ...                                     ...
# xXx                                      23
# xXx                                      24
# xXx: Return of Xander Cage                4
# Æon Flux                                  9
# Æon Flux                                  8
#
# [2527 rows x 22 columns]
