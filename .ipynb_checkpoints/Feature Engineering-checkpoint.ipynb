# %%
import pickle
import pandas as pd
import numpy as np
import datetime as dt
import re

# %%
movie_df = pickle.load(open('clean_movie_df.pickle', 'rb'))

# %%
#read holidays csv
holidays = pd.read_csv('usholidays.csv')

#convert all dates to datetime/timestamp
movie_df.release = pd.to_datetime(movie_df.release)
holidays.loc[:,'Date'] = pd.to_datetime(holidays.Date)

#filter out holiday dates before the year 2000
holidays = holidays[holidays.Date >= dt.datetime(2000,1,1)].Date

def find_closest_holiday(date):
    """
    Finds the days to the nearest US Federal Holiday
    args:
    date (timestamp)
    returns:
    nearest_hol (int) days to the nearest holiday
    """
    nearest_hol = 365
    for hol in holidays:
        d = abs((hol - date).days)
        if d < nearest_hol:
            nearest_hol = d
    return nearest_hol

movie_df['holiday_distance'] = movie_df.release.map(find_closest_holiday)

# %%
movie_df.head()
# Out:
#               index                                    link_stub    release  \
# 1663       Sin City  /release/rl3027338753/?ref_=bo_yld_table_32 2005-04-01
# 1704    Source Code  /release/rl4033906177/?ref_=bo_yld_table_60 2011-04-01
# 961       Insidious  /release/rl3428550145/?ref_=bo_yld_table_63 2011-04-01
# 881             Hop   /release/rl391874049/?ref_=bo_yld_table_25 2011-04-01
# 2479  Woman in Gold   /release/rl981108225/?ref_=bo_yld_table_77 2015-04-01
#
#       theaters                                               desc  \
# 1663      3230  A movie that explores the dark and miserable t...
# 1704      2971  A soldier wakes up in someone else's body and ...
# 961       2419  A family looks to prevent evil spirits from tr...
# 881       3616  E.B., the Easter Bunny's teenage son, heads to...
# 2479      2011  Maria Altmann, an octogenarian Jewish refugee,...
#
#                       distr   opening    budget   mpaa  runtime  ...  \
# 1663        Dimension Films  28100000  40000000      R    124.0  ...
# 1704   Summit Entertainment  14812094  32000000  PG-13     93.0  ...
# 961            FilmDistrict  13271464   1500000  PG-13    103.0  ...
# 881      Universal Pictures  37543710  63000000     PG     95.0  ...
# 2479  The Weinstein Company   2091551  11000000  PG-13    109.0  ...
#
#      gross_world                                           Director  \
# 1663   158733820  Frank Miller, Quentin Tarantino, Robert Rodriguez
# 1704   147332697                                       Duncan Jones
# 961     99557032                                          James Wan
# 881    183953723                                           Tim Hill
# 2479    61619773                                       Simon Curtis
#
#                                                  Writer  \
# 1663       Frank Miller, Robert Rodriguez, Frank Miller
# 1704                                         Ben Ripley
# 961                                      Leigh Whannell
# 881   Cinco Paul, Ken Daurio, Brian Lynch, Cinco Pau...
# 2479  Alexi Kaye Campbell, E. Randol Schoenberg, Mar...
#
#                                           Producer  \
# 1663                             Elizabeth Avellan
# 1704  Mark Gordon, Philippe Rousselet, Jordan Wynn
# 961        Jason Blum, Oren Peli, Steven Schneider
# 881       Michele Imperato, Christopher Meledandri
# 2479               David M. Thompson, Kris Thykier
#
#                                           Composer  \
# 1663  John Debney, Graeme Revell, Robert Rodriguez
# 1704                                   Chris Bacon
# 961                                 Joseph Bishara
# 881                           Christopher Lennertz
# 2479                    Martin Phipps, Hans Zimmer
#
#                         Cinematographer                           Editor  \
# 1663                   Robert Rodriguez                 Robert Rodriguez
# 1704                        Don Burgess                      Paul Hirsch
# 961   David M. Brewer, John R. Leonetti         Kirk M. Morri, James Wan
# 881               Peter Lyons Collister  Peter S. Elliot, Gregory Perler
# 2479                         Ross Emery                    Peter Lambert
#
#      Production Designer                                             Actors  \
# 1663                 nan  Mickey Rourke, Clive Owen, Bruce Willis, Jessi...
# 1704        Barry Chusid  Jake Gyllenhaal, Michelle Monaghan, Vera Farmi...
# 961           Aaron Sims  Patrick Wilson, Rose Byrne, Ty Simpkins, Lin S...
# 881      Richard Holland  Russell Brand, James Marsden, Elizabeth Perkin...
# 2479            Jim Clay  Helen Mirren, Ryan Reynolds, Daniel Brühl, Kat...
#
#      holiday_distance
# 1663               39
# 1704               39
# 961                39
# 881                39
# 2479               44
#
# [5 rows x 23 columns]

# %%
def dummies():
    #Get dummies from Genres
    movie_df = movie_df.merge(movie_df.genres.str.get_dummies(sep=','), left_index=True, right_index=True, );

    #Get dummies from movie distributor
    movie_df = movie_df.merge(pd.get_dummies(movie_df.distr), left_index=True, right_index=True);

# %%
#looking for movies with more than 1 director
#shows a small subset
movie_df.Director[movie_df.Director.str.split(pat=',').map(len)>2]
# Out:
# 1663    Frank Miller, Quentin Tarantino, Robert Rodriguez
# 624                Jeff Schaffer, Alec Berg, David Mandel
# 1264    Elizabeth Banks, Steven Brill, Steve Carr, Rus...
# 308           Mark Andrews, Brenda Chapman, Steve Purcell
# 504               Kyle Balda, Pierre Coffin, Eric Guillon
# 1170             Eric Darnell, Tom McGrath, Conrad Vernon
# 2191          Bibo Bergeron, Don Paul, Jeffrey Katzenberg
# 1655          Andrew Adamson, Kelly Asbury, Conrad Vernon
# 826            George Miller, Warren Coleman, Judy Morris
# 1256            Pete Docter, David Silverman, Lee Unkrich
# 1438           Jorge Blanco, Javier Abad, Marcos Martínez
# 1644           Bibo Bergeron, Vicky Jenson, Rob Letterman
# 912     Gabriel Riva Palacio Alatriste, Rodolfo Riva P...
# Name: Director, dtype: object

# %%
movie_df.Cinematographer[movie_df.Cinematographer.str.split(pat=',').map(len)>2]
# Out:
# 1264    Mattian Anderssonn Rudh, Frank G. DeMarco, Ste...
# 996        Lance Bangs, Dimitry Elyashkevich, Rick Kosick
# 997        Lance Bangs, Dimitry Elyashkevich, Rick Kosick
# Name: Cinematographer, dtype: object

# %%
movie_df.Composer[movie_df.Composer.str.split(pat=',').map(len)>2]
# Out:
# 1663         John Debney, Graeme Revell, Robert Rodriguez
# 1057    Marius De Vries, Ilan Eshkeri, Henry Jackman, ...
# 1324              Anthony Gonzalez, M83, Joseph Trapanese
# 1444    Shinji Miyazaki, Ralph Schuckett, Hirokazu Tanaka
# 1788    Thomas Bangalter, Guy-Manuel De Homem-Christo,...
# 108         Larry Paxton, Marty Stuart, Kristin Wilkinson
# 1678       Joseph L. Altruda, Venus Brown, Justin Stanley
# 2042             Reinhold Heil, Johnny Klimek, Tom Tykwer
# 1415          John Flansburgh, John Linnell, Joel McNeely
# 1864            Atticus Ross, Leopold Ross, Claudia Sarne
# 272     Harry Gregson-Williams, Atticus Ross, Leopold ...
# 325             Atticus Ross, Leopold Ross, Claudia Sarne
# 1264    Tyler Bates, Christophe Beck, Leo Birenberg, W...
# 116     Reinhard Besser, Oliver Lieb, Bernd Wendlandt,...
# 1185          Benny Andersson, Anne Dudley, Björn Ulvaeus
# 74           Deke Dickerson, Andrew Feltenstein, John Nau
# 1725    John Debney, Danny Elfman, Harry Gregson-Willi...
# 880               Phil Marshall, Mac McAnally, Mike Utley
# 1196     Iva Davies, Christopher Gordon, Richard Tognetti
# 94             Mick Jagger, John Powell, David A. Stewart
# 1874           Win Butler, Régine Chassagne, Owen Pallett
# 750            Gavin Friday, Quincy Jones, Maurice Seezer
# 667             Dust Brothers, John King, Michael Simpson
# 698              Headrillaz, Caspar Kedros, Darius Kedros
# 714     Explosions in the Sky, Brian Reitzell, David Torn
# 1961               Jimmy Jam, Terry Lewis, Big Jim Wright
# Name: Composer, dtype: object

# %%
movie_df.rename(columns={'gross_inter':'gross_intl'}, inplace=True)

# %%
#Get average gross income by director to get a measure of how successfull the director is. 
director_average = movie_df.groupby('Director', as_index=False)[['gross_dom', 'gross_intl', 'gross_world']].aggregate('mean')

# %%
director_average
# Out:
#                                Director    gross_dom    gross_intl  \
# 0     Aaron Horvath, Peter Rida Michail   29790236.0  2.230000e+07
# 1        Aaron Seltzer, Jason Friedberg   48548426.0  3.720061e+07
# 2           Abby Kohn, Marc Silverstein   48795601.0  4.574382e+07
# 3                            Adam McKay  115671763.8  2.913685e+07
# 4                          Adam Robitel   62375465.5  9.942337e+07
# ...                                 ...          ...           ...
# 1016        Yarrow Cheney, Scott Mosier  270620950.0  2.409750e+08
# 1017                        Yimou Zhang   49625424.5  2.065393e+08
# 1018                         Zach Braff   45018541.0  3.990000e+07
# 1019                        Zack Snyder  155802746.0  2.035224e+08
# 1020                                nan   29299580.5  4.914991e+07
#
#        gross_world
# 0     5.209024e+07
# 1     8.574903e+07
# 2     9.453943e+07
# 3     1.448086e+08
# 4     1.617988e+08
# ...            ...
# 1016  5.115960e+08
# 1017  2.561647e+08
# 1018  8.491854e+07
# 1019  3.593251e+08
# 1020  7.844949e+07
#
# [1021 rows x 4 columns]

# %%
n_movies_directed = movie_df.Director.value_counts()
n_movies_directed = pd.DataFrame(n_movies_directed).reset_index().rename(columns={'index':'Director', 'Director':'n_movies_directed'})

# %%
movie_df.rename(columns={'index':'title'}, inplace=True)

# %%
movie_df = movie_df.merge(n_movies_directed, on='Director')

# %%
movie_df.head()
# Out:
#          title                                    link_stub    release  \
# 0     Sin City  /release/rl3027338753/?ref_=bo_yld_table_32 2005-04-01
# 1  Source Code  /release/rl4033906177/?ref_=bo_yld_table_60 2011-04-01
# 2     Warcraft  /release/rl1064863233/?ref_=bo_yld_table_66 2016-06-10
# 3    Insidious  /release/rl3428550145/?ref_=bo_yld_table_63 2011-04-01
# 4    Furious 7   /release/rl1045661185/?ref_=bo_yld_table_5 2015-04-03
#
#    theaters                                               desc  \
# 0      3230  A movie that explores the dark and miserable t...
# 1      2971  A soldier wakes up in someone else's body and ...
# 2      3406  As an Orc horde invades the planet Azeroth usi...
# 3      2419  A family looks to prevent evil spirits from tr...
# 4      4022  Deckard Shaw seeks revenge against Dominic Tor...
#
#                   distr    opening     budget   mpaa  runtime  ...  \
# 0       Dimension Films   28100000   40000000      R    124.0  ...
# 1  Summit Entertainment   14812094   32000000  PG-13     93.0  ...
# 2    Universal Pictures   24166110  160000000  PG-13    123.0  ...
# 3          FilmDistrict   13271464    1500000  PG-13    103.0  ...
# 4    Universal Pictures  147187040  190000000  PG-13    137.0  ...
#
#                                             Director  \
# 0  Frank Miller, Quentin Tarantino, Robert Rodriguez
# 1                                       Duncan Jones
# 2                                       Duncan Jones
# 3                                          James Wan
# 4                                          James Wan
#
#                                          Writer  \
# 0  Frank Miller, Robert Rodriguez, Frank Miller
# 1                                    Ben Ripley
# 2                 Charles Leavitt, Duncan Jones
# 3                                Leigh Whannell
# 4             Chris Morgan, Gary Scott Thompson
#
#                                             Producer  \
# 0                                  Elizabeth Avellan
# 1       Mark Gordon, Philippe Rousselet, Jordan Wynn
# 2  Stuart Fenegan, Alex Gartner, Jon Jashni, Char...
# 3            Jason Blum, Oren Peli, Steven Schneider
# 4       Vin Diesel, Michael Fottrell, Neal H. Moritz
#
#                                        Composer  \
# 0  John Debney, Graeme Revell, Robert Rodriguez
# 1                                   Chris Bacon
# 2                                 Ramin Djawadi
# 3                                Joseph Bishara
# 4                                   Brian Tyler
#
#                      Cinematographer  \
# 0                   Robert Rodriguez
# 1                        Don Burgess
# 2                       Simon Duggan
# 3  David M. Brewer, John R. Leonetti
# 4     Marc Spicer, Stephen F. Windon
#
#                                               Editor Production Designer  \
# 0                                   Robert Rodriguez                 nan
# 1                                        Paul Hirsch        Barry Chusid
# 2                                        Paul Hirsch       Gavin Bocquet
# 3                           Kirk M. Morri, James Wan          Aaron Sims
# 4  Leigh Folsom Boyd, Dylan Highsmith, Kirk M. Mo...        Bill Brzeski
#
#                                               Actors holiday_distance  \
# 0  Mickey Rourke, Clive Owen, Bruce Willis, Jessi...               39
# 1  Jake Gyllenhaal, Michelle Monaghan, Vera Farmi...               39
# 2  Travis Fimmel, Paula Patton, Ben Foster, Domin...               11
# 3  Patrick Wilson, Rose Byrne, Ty Simpkins, Lin S...               39
# 4  Vin Diesel, Paul Walker, Dwayne Johnson, Jason...               46
#
#   n_movies_directed
# 0                 1
# 1                 2
# 2                 2
# 3                 7
# 4                 7
#
# [5 rows x 24 columns]

# %%
with open('processed_movie_df.pickle', 'wb') as to_write:
    pickle.dump(movie_df, to_write)
