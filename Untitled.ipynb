# %%
import pickle
import pandas as pd
import numpy as np
import datetime as dt
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
movie_stubs = pickle.load(open('movie_stubs.pickle', 'rb'))

# %%
ls
# Out:
# Data_Scraping_Prototype.ipynb           cast_info_list_start_to_1500.pickle
# Data_Scraping_Prototype_Selenium.ipynb  clean_movie_df.pickle
# Feature Engineering.ipynb               cleaning_prototype.ipynb
# README.md                               geckodriver.log
# Regression prototype-V2.ipynb           movie_info.pickle
# Regression prototype.ipynb              movie_stubs.pickle
# Untitled.ipynb                          processed_movie_df.pickle
# cast_info.pickle                        usholidays.csv
# cast_info_list1500_to_end.pickle

# %%
movie_stubs
# Out:
#                                                                             link_stub  \
# Avengers: Endgame                          /release/rl3059975681/?ref_=bo_yld_table_1
# The Lion King                              /release/rl3321923073/?ref_=bo_yld_table_2
# Toy Story 4                                /release/rl3798500865/?ref_=bo_yld_table_3
# Frozen II                                  /release/rl2424210945/?ref_=bo_yld_table_4
# Captain Marvel                             /release/rl3009644033/?ref_=bo_yld_table_5
# ...                                                                               ...
# Tarzan                                   /release/rl2742388225/?ref_=bo_yld_table_337
# Music of the Heart                        /release/rl761562625/?ref_=bo_yld_table_344
# The Messenger: The Story of Joan of Arc  /release/rl1986168321/?ref_=bo_yld_table_350
# Snatch                                    /release/rl141592065/?ref_=bo_yld_table_401
# The Gift                                  /release/rl945063425/?ref_=bo_yld_table_411
#
#                                               release theaters
# Avengers: Endgame                        Apr 26, 2019     4662
# The Lion King                            Jul 19, 2019     4802
# Toy Story 4                              Jun 21, 2019     4575
# Frozen II                                Nov 22, 2019     4440
# Captain Marvel                            Mar 8, 2019     4310
# ...                                               ...      ...
# Tarzan                                   Jun 16, 2000     3131
# Music of the Heart                       Oct 29, 2000     1353
# The Messenger: The Story of Joan of Arc  Nov 12, 2000     2147
# Snatch                                    Dec 8, 2000     1444
# The Gift                                 Dec 22, 2000      807
#
# [4279 rows x 3 columns]

# %%
movie_info = pickle.load(open('movie_info.pickle', 'rb'))

# %%
len(movie_info)
# Out:
# 4264

# %%
test = ['this is a test']

# %%
movie_info
# Out:
# [{'title': 'Avengers: Endgame',
#   'desc': "After the devastating events of Avengers: Infinity War, the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos' actions and restore balance to the universe.",
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$357,115,0074,662\n            theaters',
#   'budget': '$356,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '3 hr 1 min',
#   'genres': 'Action, Adventure, Drama, Sci-Fi',
#   'gross_dom': '$858,373,000',
#   'gross_inter': '$1,939,427,564',
#   'gross_world': '$2,797,800,564'},
#  {'title': 'The Lion King',
#   'desc': 'After the murder of his father, a young lion prince flees his kingdom only to learn the true meaning of responsibility and bravery.',
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$191,770,7594,725\n            theaters',
#   'budget': '$260,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 58 min',
#   'genres': 'Adventure, Animation, Drama, Family, Musical',
#   'gross_dom': '$543,638,043',
#   'gross_inter': '$1,113,305,351',
#   'gross_world': '$1,656,943,394'},
#  {'title': 'Toy Story 4',
#   'desc': 'When a new toy called "Forky" joins Woody and the gang, a road trip alongside old and new friends reveals how big the world can be for a toy.',
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$120,908,0654,575\n            theaters',
#   'budget': '$200,000,000',
#   'mpaa': 'G',
#   'runtime': '1 hr 40 min',
#   'genres': 'Adventure, Animation, Comedy, Family, Fantasy',
#   'gross_dom': '$434,038,008',
#   'gross_inter': '$639,356,585',
#   'gross_world': '$1,073,394,593'},
#  {'title': 'Frozen II',
#   'desc': "Anna, Elsa, Kristoff, Olaf and Sven leave Arendelle to travel to an ancient, autumn-bound forest of an enchanted land. They set out to find the origin of Elsa's powers in order to save their kingdom.",
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$130,263,3584,440\n            theaters',
#   'budget': '$150,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 43 min',
#   'genres': 'Adventure, Animation, Comedy, Family, Fantasy, Musical',
#   'gross_dom': '$477,373,578',
#   'gross_inter': '$972,653,355',
#   'gross_world': '$1,450,026,933'},
#  {'title': 'Captain Marvel',
#   'desc': "Carol Danvers becomes one of the universe's most powerful heroes when Earth is caught in the middle of a galactic war between two alien races.",
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$153,433,4234,310\n            theaters',
#   'budget': '$160,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 3 min',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'gross_dom': '$426,829,839',
#   'gross_inter': '$701,444,955',
#   'gross_world': '$1,128,274,794'},
#  {'title': 'Star Wars: Episode IX - The Rise of Skywalker',
#   'desc': 'The surviving members of the resistance face the First Order once again, and the legendary conflict between the Jedi and the Sith reaches its peak bringing the Skywalker saga to its end.',
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$177,383,8644,406\n            theaters',
#   'budget': '$275,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 21 min',
#   'genres': 'Action, Adventure, Fantasy, Sci-Fi',
#   'gross_dom': '$515,202,542',
#   'gross_inter': '$558,941,706',
#   'gross_world': '$1,074,144,248'},
#  {'title': 'Spider-Man: Far from Home',
#   'desc': 'Following the events of Avengers: Endgame, Spider-Man must step up to take on new threats in a world that has changed forever.',
#   'distr': 'Sony Pictures Entertainment (SPE)See full company information\n\n',
#   'opening': '$92,579,2124,634\n            theaters',
#   'budget': '$160,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 9 min',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'gross_dom': '$390,532,085',
#   'gross_inter': '$741,395,911',
#   'gross_world': '$1,131,927,996'},
#  {'title': 'Aladdin',
#   'desc': 'A kind-hearted street urchin and a power-hungry Grand Vizier vie for a magic lamp that has the power to make their deepest wishes come true.',
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$91,500,9294,476\n            theaters',
#   'budget': '$183,000,000',
#   'mpaa': 'PG',
#   'runtime': '2 hr 8 min',
#   'genres': 'Adventure, Family, Fantasy, Musical, Romance',
#   'gross_dom': '$355,559,216',
#   'gross_inter': '$695,134,737',
#   'gross_world': '$1,050,693,953'},
#  {'title': 'Joker',
#   'desc': 'In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.',
#   'distr': 'Warner Bros.See full company information\n\n',
#   'opening': '$96,202,3374,374\n            theaters',
#   'budget': '$55,000,000',
#   'mpaa': 'R',
#   'runtime': '2 hr 2 min',
#   'genres': 'Crime, Drama, Thriller',
#   'gross_dom': '$335,451,311',
#   'gross_inter': '$738,800,000',
#   'gross_world': '$1,074,251,311'},
#  {'title': 'It Chapter Two',
#   'desc': 'Twenty-seven years after their first encounter with the terrifying Pennywise, the Losers Club have grown up and moved away, until a devastating phone call brings them back.',
#   'distr': 'Warner Bros.See full company information\n\n',
#   'opening': '$91,062,1524,570\n            theaters',
#   'budget': '$79,000,000',
#   'mpaa': 'R',
#   'runtime': '2 hr 49 min',
#   'genres': 'Drama, Fantasy, Horror',
#   'gross_dom': '$211,593,228',
#   'gross_inter': '$261,500,000',
#   'gross_world': '$473,093,228'},
#  {'title': 'Jumanji: The Next Level',
#   'desc': "In Jumanji: The Next Level, the gang is back but the game has changed. As they return to rescue one of their own, the players will have to brave parts unknown from arid deserts to snowy mountains, to escape the world's most dangerous game.",
#   'distr': 'Sony Pictures Entertainment (SPE)See full company information\n\n',
#   'opening': '$59,251,5434,227\n            theaters',
#   'budget': '$125,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 3 min',
#   'genres': 'Action, Adventure, Comedy, Fantasy',
#   'gross_dom': '$316,831,246',
#   'gross_inter': '$479,744,747',
#   'gross_world': '$796,575,993'},
#  {'title': 'Us',
#   'desc': "A family's serene beach vacation turns to chaos when their doppelgängers appear and begin to terrorize them.",
#   'distr': 'Universal PicturesSee full company information\n\n',
#   'opening': '$71,117,6253,741\n            theaters',
#   'budget': '$20,000,000',
#   'mpaa': 'R',
#   'runtime': '1 hr 56 min',
#   'genres': 'Horror, Mystery, Thriller',
#   'gross_dom': '$175,084,580',
#   'gross_inter': '$80,100,000',
#   'gross_world': '$255,184,580'},
#  {'title': 'Fast & Furious Presents: Hobbs & Shaw',
#   'desc': 'Lawman Luke Hobbs (Dwayne "The Rock" Johnson) and outcast Deckard Shaw (Jason Statham) form an unlikely alliance when a cyber-genetically enhanced villain threatens the future of humanity.',
#   'distr': 'Universal PicturesSee full company information\n\n',
#   'opening': '$60,038,9504,253\n            theaters',
#   'budget': '$200,000,000',
#   'mpaa': None,
#   'runtime': '2 hr 17 min',
#   'genres': 'Action, Adventure, Thriller',
#   'gross_dom': '$173,956,935',
#   'gross_inter': '$585,100,000',
#   'gross_world': '$759,056,935'},
#  {'title': 'John Wick: Chapter 3 - Parabellum',
#   'desc': "John Wick is on the run after killing a member of the international assassins' guild, and with a $14 million price tag on his head, he is the target of hit men and women everywhere.",
#   'distr': 'LionsgateSee full company information\n\n',
#   'opening': '$56,818,0673,850\n            theaters',
#   'budget': '$75,000,000',
#   'mpaa': 'R',
#   'runtime': '2 hr 10 min',
#   'genres': 'Action, Crime, Thriller',
#   'gross_dom': '$171,015,687',
#   'gross_inter': '$155,694,040',
#   'gross_world': '$326,709,727'},
#  {'title': 'How to Train Your Dragon: The Hidden World',
#   'desc': 'When Hiccup discovers Toothless isn\'t the only Night Fury, he must seek "The Hidden World", a secret Dragon Utopia before a hired tyrant named Grimmel finds it first.',
#   'distr': 'Universal PicturesSee full company information\n\n',
#   'opening': '$55,022,2454,259\n            theaters',
#   'budget': '$129,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 44 min',
#   'genres': 'Action, Adventure, Animation, Family, Fantasy',
#   'gross_dom': '$160,799,505',
#   'gross_inter': '$361,000,000',
#   'gross_world': '$521,799,505'},
#  {'title': 'The Secret Life of Pets 2',
#   'desc': 'Continuing the story of Max and his pet friends, following their secret lives after their owners leave them for work or school each day.',
#   'distr': 'Universal PicturesSee full company information\n\n',
#   'opening': '$46,652,6804,561\n            theaters',
#   'budget': '$80,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 26 min',
#   'genres': 'Adventure, Animation, Comedy, Family',
#   'gross_dom': '$158,874,395',
#   'gross_inter': '$271,176,898',
#   'gross_world': '$430,051,293'},
#  {'title': 'Avengers: Endgame',
#   'desc': "After the devastating events of Avengers: Infinity War, the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos' actions and restore balance to the universe.",
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$357,115,0074,662\n            theaters',
#   'budget': '$356,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '3 hr 1 min',
#   'genres': 'Action, Adventure, Drama, Sci-Fi',
#   'gross_dom': '$858,373,000',
#   'gross_inter': '$1,939,427,564',
#   'gross_world': '$2,797,800,564'},
#  {'title': 'The Lion King',
#   'desc': 'After the murder of his father, a young lion prince flees his kingdom only to learn the true meaning of responsibility and bravery.',
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$191,770,7594,725\n            theaters',
#   'budget': '$260,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 58 min',
#   'genres': 'Adventure, Animation, Drama, Family, Musical',
#   'gross_dom': '$543,638,043',
#   'gross_inter': '$1,113,305,351',
#   'gross_world': '$1,656,943,394'},
#  {'title': 'Toy Story 4',
#   'desc': 'When a new toy called "Forky" joins Woody and the gang, a road trip alongside old and new friends reveals how big the world can be for a toy.',
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$120,908,0654,575\n            theaters',
#   'budget': '$200,000,000',
#   'mpaa': 'G',
#   'runtime': '1 hr 40 min',
#   'genres': 'Adventure, Animation, Comedy, Family, Fantasy',
#   'gross_dom': '$434,038,008',
#   'gross_inter': '$639,356,585',
#   'gross_world': '$1,073,394,593'},
#  {'title': 'Frozen II',
#   'desc': "Anna, Elsa, Kristoff, Olaf and Sven leave Arendelle to travel to an ancient, autumn-bound forest of an enchanted land. They set out to find the origin of Elsa's powers in order to save their kingdom.",
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$130,263,3584,440\n            theaters',
#   'budget': '$150,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 43 min',
#   'genres': 'Adventure, Animation, Comedy, Family, Fantasy, Musical',
#   'gross_dom': '$477,373,578',
#   'gross_inter': '$972,653,355',
#   'gross_world': '$1,450,026,933'},
#  {'title': 'Captain Marvel',
#   'desc': "Carol Danvers becomes one of the universe's most powerful heroes when Earth is caught in the middle of a galactic war between two alien races.",
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$153,433,4234,310\n            theaters',
#   'budget': '$160,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 3 min',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'gross_dom': '$426,829,839',
#   'gross_inter': '$701,444,955',
#   'gross_world': '$1,128,274,794'},
#  {'title': 'Star Wars: Episode IX - The Rise of Skywalker',
#   'desc': 'The surviving members of the resistance face the First Order once again, and the legendary conflict between the Jedi and the Sith reaches its peak bringing the Skywalker saga to its end.',
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$177,383,8644,406\n            theaters',
#   'budget': '$275,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 21 min',
#   'genres': 'Action, Adventure, Fantasy, Sci-Fi',
#   'gross_dom': '$515,202,542',
#   'gross_inter': '$558,941,706',
#   'gross_world': '$1,074,144,248'},
#  {'title': 'Spider-Man: Far from Home',
#   'desc': 'Following the events of Avengers: Endgame, Spider-Man must step up to take on new threats in a world that has changed forever.',
#   'distr': 'Sony Pictures Entertainment (SPE)See full company information\n\n',
#   'opening': '$92,579,2124,634\n            theaters',
#   'budget': '$160,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 9 min',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'gross_dom': '$390,532,085',
#   'gross_inter': '$741,395,911',
#   'gross_world': '$1,131,927,996'},
#  {'title': 'Aladdin',
#   'desc': 'A kind-hearted street urchin and a power-hungry Grand Vizier vie for a magic lamp that has the power to make their deepest wishes come true.',
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$91,500,9294,476\n            theaters',
#   'budget': '$183,000,000',
#   'mpaa': 'PG',
#   'runtime': '2 hr 8 min',
#   'genres': 'Adventure, Family, Fantasy, Musical, Romance',
#   'gross_dom': '$355,559,216',
#   'gross_inter': '$695,134,737',
#   'gross_world': '$1,050,693,953'},
#  {'title': 'Joker',
#   'desc': 'In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.',
#   'distr': 'Warner Bros.See full company information\n\n',
#   'opening': '$96,202,3374,374\n            theaters',
#   'budget': '$55,000,000',
#   'mpaa': 'R',
#   'runtime': '2 hr 2 min',
#   'genres': 'Crime, Drama, Thriller',
#   'gross_dom': '$335,451,311',
#   'gross_inter': '$738,800,000',
#   'gross_world': '$1,074,251,311'},
#  {'title': 'It Chapter Two',
#   'desc': 'Twenty-seven years after their first encounter with the terrifying Pennywise, the Losers Club have grown up and moved away, until a devastating phone call brings them back.',
#   'distr': 'Warner Bros.See full company information\n\n',
#   'opening': '$91,062,1524,570\n            theaters',
#   'budget': '$79,000,000',
#   'mpaa': 'R',
#   'runtime': '2 hr 49 min',
#   'genres': 'Drama, Fantasy, Horror',
#   'gross_dom': '$211,593,228',
#   'gross_inter': '$261,500,000',
#   'gross_world': '$473,093,228'},
#  {'title': 'Jumanji: The Next Level',
#   'desc': "In Jumanji: The Next Level, the gang is back but the game has changed. As they return to rescue one of their own, the players will have to brave parts unknown from arid deserts to snowy mountains, to escape the world's most dangerous game.",
#   'distr': 'Sony Pictures Entertainment (SPE)See full company information\n\n',
#   'opening': '$59,251,5434,227\n            theaters',
#   'budget': '$125,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 3 min',
#   'genres': 'Action, Adventure, Comedy, Fantasy',
#   'gross_dom': '$316,831,246',
#   'gross_inter': '$479,744,747',
#   'gross_world': '$796,575,993'},
#  {'title': 'Us',
#   'desc': "A family's serene beach vacation turns to chaos when their doppelgängers appear and begin to terrorize them.",
#   'distr': 'Universal PicturesSee full company information\n\n',
#   'opening': '$71,117,6253,741\n            theaters',
#   'budget': '$20,000,000',
#   'mpaa': 'R',
#   'runtime': '1 hr 56 min',
#   'genres': 'Horror, Mystery, Thriller',
#   'gross_dom': '$175,084,580',
#   'gross_inter': '$80,100,000',
#   'gross_world': '$255,184,580'},
#  {'title': 'Fast & Furious Presents: Hobbs & Shaw',
#   'desc': 'Lawman Luke Hobbs (Dwayne "The Rock" Johnson) and outcast Deckard Shaw (Jason Statham) form an unlikely alliance when a cyber-genetically enhanced villain threatens the future of humanity.',
#   'distr': 'Universal PicturesSee full company information\n\n',
#   'opening': '$60,038,9504,253\n            theaters',
#   'budget': '$200,000,000',
#   'mpaa': None,
#   'runtime': '2 hr 17 min',
#   'genres': 'Action, Adventure, Thriller',
#   'gross_dom': '$173,956,935',
#   'gross_inter': '$585,100,000',
#   'gross_world': '$759,056,935'},
#  {'title': 'John Wick: Chapter 3 - Parabellum',
#   'desc': "John Wick is on the run after killing a member of the international assassins' guild, and with a $14 million price tag on his head, he is the target of hit men and women everywhere.",
#   'distr': 'LionsgateSee full company information\n\n',
#   'opening': '$56,818,0673,850\n            theaters',
#   'budget': '$75,000,000',
#   'mpaa': 'R',
#   'runtime': '2 hr 10 min',
#   'genres': 'Action, Crime, Thriller',
#   'gross_dom': '$171,015,687',
#   'gross_inter': '$155,694,040',
#   'gross_world': '$326,709,727'},
#  {'title': 'How to Train Your Dragon: The Hidden World',
#   'desc': 'When Hiccup discovers Toothless isn\'t the only Night Fury, he must seek "The Hidden World", a secret Dragon Utopia before a hired tyrant named Grimmel finds it first.',
#   'distr': 'Universal PicturesSee full company information\n\n',
#   'opening': '$55,022,2454,259\n            theaters',
#   'budget': '$129,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 44 min',
#   'genres': 'Action, Adventure, Animation, Family, Fantasy',
#   'gross_dom': '$160,799,505',
#   'gross_inter': '$361,000,000',
#   'gross_world': '$521,799,505'},
#  {'title': 'The Secret Life of Pets 2',
#   'desc': 'Continuing the story of Max and his pet friends, following their secret lives after their owners leave them for work or school each day.',
#   'distr': 'Universal PicturesSee full company information\n\n',
#   'opening': '$46,652,6804,561\n            theaters',
#   'budget': '$80,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 26 min',
#   'genres': 'Adventure, Animation, Comedy, Family',
#   'gross_dom': '$158,874,395',
#   'gross_inter': '$271,176,898',
#   'gross_world': '$430,051,293'},
#  {'title': 'Pokémon Detective Pikachu',
#   'desc': 'In a world where people collect Pokémon to do battle, a boy comes across an intelligent talking Pikachu who seeks to be a detective.',
#   'distr': 'Warner Bros.See full company information\n\n',
#   'opening': '$54,365,2424,202\n            theaters',
#   'budget': '$150,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 44 min',
#   'genres': 'Action, Adventure, Comedy, Family, Mystery, Sci-Fi',
#   'gross_dom': '$144,105,346',
#   'gross_inter': '$288,900,000',
#   'gross_world': '$433,005,346'},
#  {'title': 'Once Upon a Time... In Hollywood',
#   'desc': "A faded television actor and his stunt double strive to achieve fame and success in the final years of Hollywood's Golden Age in 1969 Los Angeles.",
#   'distr': 'Sony Pictures Entertainment (SPE)See full company information\n\n',
#   'opening': '$41,082,0183,659\n            theaters',
#   'budget': '$90,000,000',
#   'mpaa': 'R',
#   'runtime': '2 hr 41 min',
#   'genres': 'Comedy, Drama',
#   'gross_dom': '$142,502,728',
#   'gross_inter': '$231,840,898',
#   'gross_world': '$374,343,626'},
#  {'title': 'Shazam!',
#   'desc': 'A newly fostered young boy in search of his mother instead finds unexpected super powers and soon gains a powerful enemy.',
#   'distr': 'Warner Bros.See full company information\n\n',
#   'opening': '$53,505,3264,217\n            theaters',
#   'budget': '$100,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 12 min',
#   'genres': 'Action, Adventure, Comedy, Fantasy',
#   'gross_dom': '$140,371,656',
#   'gross_inter': '$225,600,000',
#   'gross_world': '$365,971,656'},
#  {'title': 'Aquaman',
#   'desc': 'Arthur Curry, the human-born heir to the underwater kingdom of Atlantis, goes on a quest to prevent a war between the worlds of ocean and land.',
#   'distr': 'Warner Bros.See full company information\n\n',
#   'opening': '$67,873,5224,125\n            theaters',
#   'budget': None,
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 23 min',
#   'genres': 'Action, Adventure, Fantasy, Sci-Fi',
#   'gross_dom': '$335,061,807',
#   'gross_inter': '$813,400,000',
#   'gross_world': '$1,148,461,807'},
#  {'title': 'Knives Out',
#   'desc': 'A detective investigates the death of a patriarch of an eccentric, combative family.',
#   'distr': 'LionsgateSee full company information\n\n',
#   'opening': '$26,769,5483,461\n            theaters',
#   'budget': '$40,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 10 min',
#   'genres': 'Comedy, Crime, Drama, Mystery, Thriller',
#   'gross_dom': '$165,363,234',
#   'gross_inter': '$143,869,563',
#   'gross_world': '$309,232,797'},
#  {'title': 'Dumbo',
#   'desc': 'A young elephant, whose oversized ears enable him to fly, helps save a struggling circus, but when the circus plans a new venture, Dumbo and his friends discover dark secrets beneath its shiny veneer.',
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$45,990,7484,259\n            theaters',
#   'budget': '$170,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 52 min',
#   'genres': 'Adventure, Family, Fantasy',
#   'gross_dom': '$114,766,307',
#   'gross_inter': '$238,518,314',
#   'gross_world': '$353,284,621'},
#  {'title': 'Maleficent: Mistress of Evil',
#   'desc': 'Maleficent and her goddaughter Aurora begin to question the complex family ties that bind them as they are pulled in different directions by impending nuptials, unexpected allies and dark new forces at play.',
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$36,948,7133,790\n            theaters',
#   'budget': '$185,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 59 min',
#   'genres': 'Adventure, Family, Fantasy',
#   'gross_dom': '$113,929,605',
#   'gross_inter': '$377,800,484',
#   'gross_world': '$491,730,089'},
#  {'title': 'Glass',
#   'desc': 'Security guard David Dunn uses his supernatural abilities to track Kevin Wendell Crumb, a disturbed man who has twenty-four personalities.',
#   'distr': 'Universal PicturesSee full company information\n\n',
#   'opening': '$40,328,9203,841\n            theaters',
#   'budget': '$20,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 9 min',
#   'genres': 'Drama, Sci-Fi, Thriller',
#   'gross_dom': '$111,048,468',
#   'gross_inter': '$135,950,571',
#   'gross_world': '$246,999,039'},
#  {'title': 'Godzilla: King of the Monsters',
#   'desc': 'The crypto-zoological agency Monarch faces off against a battery of god-sized monsters, including the mighty Godzilla, who collides with Mothra, Rodan, and his ultimate nemesis, the three-headed King Ghidorah.',
#   'distr': 'Warner Bros.See full company information\n\n',
#   'opening': '$47,776,2934,108\n            theaters',
#   'budget': '$170,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 12 min',
#   'genres': 'Action, Adventure, Fantasy, Sci-Fi',
#   'gross_dom': '$110,500,138',
#   'gross_inter': '$276,100,000',
#   'gross_world': '$386,600,138'},
#  {'title': 'The Upside',
#   'desc': "A comedic look at the relationship between a wealthy man with quadriplegia and an unemployed man with a criminal record who's hired to help him.",
#   'distr': 'STX EntertainmentSee full company information\n\n',
#   'opening': '$20,355,0003,080\n            theaters',
#   'budget': '$37,500,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 6 min',
#   'genres': 'Comedy, Drama',
#   'gross_dom': '$108,252,517',
#   'gross_inter': '$17,600,000',
#   'gross_world': '$125,852,517'},
#  {'title': 'Ford v Ferrari',
#   'desc': 'American car designer Carroll Shelby and driver Ken Miles battle corporate interference and the laws of physics to build a revolutionary race car for Ford in order to defeat Ferrari at the 24 Hours of Le Mans in 1966.',
#   'distr': 'Twentieth Century FoxSee full company information\n\n',
#   'opening': '$31,474,9583,528\n            theaters',
#   'budget': '$97,600,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 32 min',
#   'genres': 'Action, Biography, Drama, Sport',
#   'gross_dom': '$117,624,357',
#   'gross_inter': '$107,883,853',
#   'gross_world': '$225,508,210'},
#  {'title': 'The LEGO Movie 2: The Second Part',
#   'desc': "It's been five years since everything was awesome and the citizens are facing a huge new threat: Lego Duplo invaders from outer space, wrecking everything faster than they can rebuild.",
#   'distr': 'Warner Bros.See full company information\n\n',
#   'opening': '$34,115,3354,303\n            theaters',
#   'budget': '$99,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 47 min',
#   'genres': 'Adventure, Animation, Comedy, Family, Fantasy, Musical',
#   'gross_dom': '$105,806,508',
#   'gross_inter': '$86,500,000',
#   'gross_world': '$192,306,508'},
#  {'title': 'Hustlers',
#   'desc': 'Inspired by the viral New York Magazine article, Hustlers follows a crew of savvy former strip club employees who band together to turn the tables on their Wall Street clients.',
#   'distr': 'STX EntertainmentSee full company information\n\n',
#   'opening': '$33,181,3613,250\n            theaters',
#   'budget': '$20,000,000',
#   'mpaa': 'R',
#   'runtime': '1 hr 50 min',
#   'genres': 'Comedy, Crime, Drama, Thriller',
#   'gross_dom': '$104,963,598',
#   'gross_inter': '$52,600,000',
#   'gross_world': '$157,563,598'},
#  {'title': 'The Addams Family',
#   'desc': "The eccentrically macabre family moves to a bland suburb where Wednesday Addams' friendship with the daughter of a hostile and conformist local reality show host exacerbates conflict between the families.",
#   'distr': 'United Artists ReleasingSee full company information\n\n',
#   'opening': '$30,300,0074,007\n            theaters',
#   'budget': '$24,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 26 min',
#   'genres': 'Animation, Comedy, Family, Fantasy, Horror',
#   'gross_dom': '$100,044,905',
#   'gross_inter': '$103,000,000',
#   'gross_world': '$203,044,905'},
#  {'title': 'Downton Abbey',
#   'desc': 'The continuing story of the Crawley family, wealthy owners of a large estate in the English countryside in the early twentieth century.',
#   'distr': 'Focus FeaturesSee full company information\n\n',
#   'opening': '$31,033,6653,079\n            theaters',
#   'budget': '$13,000,000',
#   'mpaa': 'PG',
#   'runtime': '2 hr 2 min',
#   'genres': 'Drama, Romance',
#   'gross_dom': '$96,854,135',
#   'gross_inter': '$96,966,620',
#   'gross_world': '$193,820,755'},
#  {'title': 'Rocketman',
#   'desc': "A musical fantasy about the fantastical human story of Elton John's breakthrough years.",
#   'distr': 'Paramount PicturesSee full company information\n\n',
#   'opening': '$25,725,7223,610\n            theaters',
#   'budget': '$40,000,000',
#   'mpaa': 'R',
#   'runtime': '2 hr 1 min',
#   'genres': 'Biography, Drama, Music, Musical',
#   'gross_dom': '$96,368,160',
#   'gross_inter': '$98,811,139',
#   'gross_world': '$195,179,299'},
#  {'title': 'Alita: Battle Angel',
#   'desc': "A deactivated cyborg's revived, but can't remember anything of her past and goes on a quest to find out who she is.",
#   'distr': 'Twentieth Century FoxSee full company information\n\n',
#   'opening': '$28,525,6133,790\n            theaters',
#   'budget': '$170,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 2 min',
#   'genres': 'Action, Adventure, Sci-Fi, Thriller',
#   'gross_dom': '$85,710,210',
#   'gross_inter': '$319,142,333',
#   'gross_world': '$404,852,543'},
#  {'title': 'Good Boys',
#   'desc': 'Three 6th grade boys ditch school and embark on an epic journey while carrying accidentally stolen drugs, being hunted by teenage girls, and trying to make their way home in time for a long-awaited party.',
#   'distr': 'Universal PicturesSee full company information\n\n',
#   'opening': '$21,402,6053,204\n            theaters',
#   'budget': '$20,000,000',
#   'mpaa': 'R',
#   'runtime': '1 hr 30 min',
#   'genres': 'Adventure, Comedy',
#   'gross_dom': '$83,140,306',
#   'gross_inter': '$27,896,926',
#   'gross_world': '$111,037,232'},
#  {'title': 'Spider-Man: Into the Spider-Verse',
#   'desc': 'Teen Miles Morales becomes the Spider-Man of his universe, and must join with five spider-powered individuals from other dimensions to stop a threat for all realities.',
#   'distr': 'Sony Pictures Entertainment (SPE)See full company information\n\n',
#   'opening': '$35,363,3763,813\n            theaters',
#   'budget': None,
#   'mpaa': 'PG',
#   'runtime': '1 hr 57 min',
#   'genres': 'Action, Adventure, Animation, Family, Sci-Fi',
#   'gross_dom': '$190,241,310',
#   'gross_inter': '$185,299,521',
#   'gross_world': '$375,540,831'},
#  {'title': 'Men in Black: International',
#   'desc': 'The Men in Black have always protected the Earth from the scum of the universe. In this new adventure, they tackle their biggest threat to date: a mole in the Men in Black organization.',
#   'distr': 'Sony Pictures Entertainment (SPE)See full company information\n\n',
#   'opening': '$30,035,8384,224\n            theaters',
#   'budget': '$110,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 54 min',
#   'genres': 'Action, Adventure, Comedy, Sci-Fi',
#   'gross_dom': '$80,001,807',
#   'gross_inter': '$173,888,894',
#   'gross_world': '$253,890,701'},
#  {'title': 'Annabelle Comes Home',
#   'desc': 'While babysitting the daughter of Ed and Lorraine Warren, a teenager and her friend unknowingly awaken an evil spirit trapped in a doll.',
#   'distr': 'Warner Bros.See full company information\n\n',
#   'opening': '$20,269,7233,613\n            theaters',
#   'budget': '$30,000,000',
#   'mpaa': 'R',
#   'runtime': '1 hr 46 min',
#   'genres': 'Horror, Mystery, Thriller',
#   'gross_dom': '$74,152,591',
#   'gross_inter': '$157,100,000',
#   'gross_world': '$231,252,591'},
#  {'title': 'Yesterday',
#   'desc': "A struggling musician realizes he's the only person on Earth who can remember The Beatles after waking up in an alternate timeline where they never existed.",
#   'distr': 'Universal PicturesSee full company information\n\n',
#   'opening': '$17,010,0502,603\n            theaters',
#   'budget': '$26,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 56 min',
#   'genres': 'Comedy, Fantasy, Music, Romance',
#   'gross_dom': '$73,286,650',
#   'gross_inter': '$79,723,934',
#   'gross_world': '$153,010,584'},
#  {'title': "Tyler Perry's a Madea Family Funeral",
#   'desc': 'A joyous family reunion becomes a hilarious nightmare as Madea and the crew travel to backwoods Georgia, where they find themselves unexpectedly planning a funeral that might unveil unsavory family secrets.',
#   'distr': 'LionsgateSee full company information\n\n',
#   'opening': '$27,062,3322,442\n            theaters',
#   'budget': '$20,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 49 min',
#   'genres': 'Comedy',
#   'gross_dom': '$73,257,045',
#   'gross_inter': '$1,490,680',
#   'gross_world': '$74,747,725'},
#  {'title': 'Zombieland: Double Tap',
#   'desc': 'Columbus, Tallahassee, Wichita, and Little Rock move to the American heartland as they face off against evolved zombies, fellow survivors, and the growing pains of the snarky makeshift family.',
#   'distr': 'Sony Pictures Entertainment (SPE)See full company information\n\n',
#   'opening': '$26,803,1043,468\n            theaters',
#   'budget': '$42,000,000',
#   'mpaa': 'R',
#   'runtime': '1 hr 39 min',
#   'genres': 'Action, Adventure, Comedy, Horror',
#   'gross_dom': '$73,123,082',
#   'gross_inter': '$49,687,317',
#   'gross_world': '$122,810,399'},
#  {'title': 'Angel Has Fallen',
#   'desc': 'Mike Banning is framed for the attempted assassination of the President and must evade his own agency and the FBI as he tries to uncover the real threat.',
#   'distr': 'LionsgateSee full company information\n\n',
#   'opening': '$21,380,9873,286\n            theaters',
#   'budget': '$40,000,000',
#   'mpaa': 'R',
#   'runtime': '2 hr 1 min',
#   'genres': 'Action, Thriller',
#   'gross_dom': '$69,030,436',
#   'gross_inter': '$77,631,541',
#   'gross_world': '$146,661,977'},
#  {'title': 'Scary Stories to Tell in the Dark',
#   'desc': 'On Halloween 1968, Stella and her two friends meet a mysterious drifter, Ramón, and uncover a sinister notebook of stories.',
#   'distr': 'LionsgateSee full company information\n\n',
#   'opening': '$20,915,3463,135\n            theaters',
#   'budget': '$25,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 48 min',
#   'genres': 'Adventure, Horror, Mystery, Thriller',
#   'gross_dom': '$68,947,075',
#   'gross_inter': '$35,598,430',
#   'gross_world': '$104,545,505'},
#  {'title': 'Mary Poppins Returns',
#   'desc': "A few decades after her original visit, Mary Poppins, the magical nanny, returns to help the Banks siblings and Michael's children through a difficult time in their lives.",
#   'distr': 'Walt Disney Studios Motion PicturesSee full company information\n\n',
#   'opening': '$23,523,1214,090\n            theaters',
#   'budget': '$130,000,000',
#   'mpaa': 'PG',
#   'runtime': '2 hr 10 min',
#   'genres': 'Comedy, Family, Fantasy, Musical',
#   'gross_dom': '$171,958,438',
#   'gross_inter': '$177,579,056',
#   'gross_world': '$349,537,494'},
#  {'title': 'X-Men: Dark Phoenix',
#   'desc': 'Jean Grey begins to develop incredible powers that corrupt and turn her into a Dark Phoenix, causing the X-Men to decide if her life is worth more than all of humanity.',
#   'distr': 'Twentieth Century FoxSee full company information\n\n',
#   'opening': '$32,828,3483,721\n            theaters',
#   'budget': '$200,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 53 min',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'gross_dom': '$65,845,974',
#   'gross_inter': '$186,597,000',
#   'gross_world': '$252,442,974'},
#  {'title': 'Terminator: Dark Fate',
#   'desc': 'An augmented human and Sarah Connor must stop an advanced liquid Terminator from hunting down a young girl, whose fate is critical to the human race.',
#   'distr': 'Paramount PicturesSee full company information\n\n',
#   'opening': '$29,033,8324,086\n            theaters',
#   'budget': '$185,000,000',
#   'mpaa': 'R',
#   'runtime': '2 hr 8 min',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'gross_dom': '$62,253,077',
#   'gross_inter': '$198,866,215',
#   'gross_world': '$261,119,292'},
#  {'title': 'Abominable',
#   'desc': 'Three teenagers must help a Yeti return to his family while avoiding a wealthy man and a zoologist who want him for their own needs.',
#   'distr': 'Universal PicturesSee full company information\n\n',
#   'opening': '$20,612,1004,242\n            theaters',
#   'budget': '$75,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 37 min',
#   'genres': 'Adventure, Animation, Comedy, Family, Fantasy',
#   'gross_dom': '$60,716,390',
#   'gross_inter': '$118,311,851',
#   'gross_world': '$179,028,241'},
#  {'title': 'Dora and the Lost City of Gold',
#   'desc': 'Dora, a teenage explorer, leads her friends on an adventure to save her parents and solve the mystery behind a lost city of gold.',
#   'distr': 'Paramount PicturesSee full company information\n\n',
#   'opening': '$17,431,5883,735\n            theaters',
#   'budget': '$49,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 42 min',
#   'genres': 'Adventure, Comedy, Family, Mystery',
#   'gross_dom': '$60,477,943',
#   'gross_inter': '$59,204,692',
#   'gross_world': '$119,682,635'},
#  {'title': 'Escape Room',
#   'desc': 'Six strangers find themselves in a maze of deadly mystery rooms and must use their wits to survive.',
#   'distr': 'Sony Pictures Entertainment (SPE)See full company information\n\n',
#   'opening': '$18,238,1722,717\n            theaters',
#   'budget': '$9,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 39 min',
#   'genres': 'Action, Adventure, Horror, Mystery, Thriller',
#   'gross_dom': '$57,005,601',
#   'gross_inter': '$98,706,476',
#   'gross_world': '$155,712,077'},
#  {'title': 'A Beautiful Day in the Neighborhood',
#   'desc': 'Based on the true story of a real-life friendship between Fred Rogers and journalist Lloyd Vogel.',
#   'distr': 'Sony Pictures Entertainment (SPE)See full company information\n\n',
#   'opening': '$13,251,2383,235\n            theaters',
#   'budget': '$25,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 49 min',
#   'genres': 'Biography, Drama',
#   'gross_dom': '$61,704,055',
#   'gross_inter': '$6,056,822',
#   'gross_world': '$67,760,877'},
#  {'title': 'Midway',
#   'desc': 'The story of the Battle of Midway, told by the leaders and the sailors who fought it.',
#   'distr': 'LionsgateSee full company information\n\n',
#   'opening': '$17,897,4193,242\n            theaters',
#   'budget': '$100,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 18 min',
#   'genres': 'Action, Adventure, Drama, History, War',
#   'gross_dom': '$56,846,802',
#   'gross_inter': '$69,849,673',
#   'gross_world': '$126,696,475'},
#  {'title': 'Bumblebee',
#   'desc': 'On the run in the year 1987, Bumblebee finds refuge in a junkyard in a small California beach town. On the cusp of turning 18 and trying to find her place in the world, Charlie Watson discovers Bumblebee, battle-scarred and broken.',
#   'distr': 'Paramount PicturesSee full company information\n\n',
#   'opening': '$21,654,0473,550\n            theaters',
#   'budget': '$135,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 54 min',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'gross_dom': '$127,195,589',
#   'gross_inter': '$340,794,056',
#   'gross_world': '$467,989,645'},
#  {'title': 'The Curse of La Llorona',
#   'desc': 'Ignoring the eerie warning of a troubled mother suspected of child endangerment, a social worker and her own small kids are soon drawn into a frightening supernatural realm.',
#   'distr': 'Warner Bros.See full company information\n\n',
#   'opening': '$26,347,6313,372\n            theaters',
#   'budget': '$9,000,000',
#   'mpaa': 'R',
#   'runtime': '1 hr 33 min',
#   'genres': 'Horror, Mystery, Thriller',
#   'gross_dom': '$54,733,739',
#   'gross_inter': '$68,400,000',
#   'gross_world': '$123,133,739'},
#  {'title': 'Pet Sematary',
#   'desc': 'Dr. Louis Creed and his wife, Rachel, relocate from Boston to rural Maine with their two young children. The couple soon discover a mysterious burial ground hidden deep in the woods near their new home.',
#   'distr': 'Paramount PicturesSee full company information\n\n',
#   'opening': '$24,502,7753,585\n            theaters',
#   'budget': '$21,000,000',
#   'mpaa': 'R',
#   'runtime': '1 hr 41 min',
#   'genres': 'Horror, Mystery, Thriller',
#   'gross_dom': '$54,724,696',
#   'gross_inter': '$58,393,530',
#   'gross_world': '$113,118,226'},
#  {'title': 'What Men Want',
#   'desc': "A woman is boxed out by the male sports agents in her profession, but gains an unexpected edge over them when she develops the ability to hear men's thoughts.",
#   'distr': 'Paramount PicturesSee full company information\n\n',
#   'opening': '$18,232,0872,912\n            theaters',
#   'budget': '$20,000,000',
#   'mpaa': 'R',
#   'runtime': '1 hr 57 min',
#   'genres': 'Comedy, Fantasy, Romance',
#   'gross_dom': '$54,611,903',
#   'gross_inter': '$17,604,391',
#   'gross_world': '$72,216,294'},
#  {'title': 'Green Book',
#   'desc': 'A working-class Italian-American bouncer becomes the driver of an African-American classical pianist on a tour of venues through the 1960s American South.',
#   'distr': 'Universal PicturesSee full company information\n\n',
#   'opening': '$320,42925\n            theaters',
#   'budget': '$23,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 10 min',
#   'genres': 'Biography, Comedy, Drama, Music',
#   'gross_dom': '$85,080,171',
#   'gross_inter': '$236,672,485',
#   'gross_world': '$321,752,656'},
#  {'title': 'Ad Astra',
#   'desc': 'Astronaut Roy McBride undertakes a mission across an unforgiving solar system to uncover the truth about his missing father and his doomed expedition that now, 30 years later, threatens the universe.',
#   'distr': 'Twentieth Century FoxSee full company information\n\n',
#   'opening': '$19,001,3983,460\n            theaters',
#   'budget': '$90,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 3 min',
#   'genres': 'Adventure, Drama, Mystery, Sci-Fi, Thriller',
#   'gross_dom': '$50,188,370',
#   'gross_inter': '$77,273,502',
#   'gross_world': '$127,461,872'},
#  {'title': "Isn't It Romantic",
#   'desc': 'A young woman disenchanted with love mysteriously finds herself trapped inside a romantic comedy.',
#   'distr': 'Warner Bros.See full company information\n\n',
#   'opening': '$14,247,7583,444\n            theaters',
#   'budget': '$31,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 29 min',
#   'genres': 'Comedy, Fantasy, Romance',
#   'gross_dom': '$48,791,187',
#   'gross_inter': '$48,791,187'},
#  {'title': 'Gemini Man',
#   'desc': 'An over-the-hill hitman faces off against a younger clone of himself.',
#   'distr': 'Paramount PicturesSee full company information\n\n',
#   'opening': '$20,552,3723,642\n            theaters',
#   'budget': '$138,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 57 min',
#   'genres': 'Action, Drama, Sci-Fi, Thriller',
#   'gross_dom': '$48,546,770',
#   'gross_inter': '$124,922,746',
#   'gross_world': '$173,469,516'},
#  {'title': 'Ma',
#   'desc': "A lonely woman befriends a group of teenagers and decides to let them party at her house. Just when the kids think their luck couldn't get any better, things start happening that make them question the intention of their host.",
#   'distr': 'Universal PicturesSee full company information\n\n',
#   'opening': '$18,099,8052,808\n            theaters',
#   'budget': '$5,000,000',
#   'mpaa': 'R',
#   'runtime': '1 hr 39 min',
#   'genres': 'Horror, Mystery, Thriller',
#   'gross_dom': '$45,896,028',
#   'gross_inter': '$15,209,644',
#   'gross_world': '$61,105,672'},
#  {'title': 'Five Feet Apart',
#   'desc': 'A pair of teenagers with cystic fibrosis meet in a hospital and fall in love, though their disease means they must avoid close physical contact.',
#   'distr': 'LionsgateSee full company information\n\n',
#   'opening': '$13,190,2862,803\n            theaters',
#   'budget': '$7,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 56 min',
#   'genres': 'Drama, Romance',
#   'gross_dom': '$45,729,221',
#   'gross_inter': '$45,792,873',
#   'gross_world': '$91,522,094'},
#  {'title': 'Wonder Park',
#   'desc': 'Wonder Park tells the story of an amusement park where the imagination of a wildly creative girl named June comes alive.',
#   'distr': 'Paramount PicturesSee full company information\n\n',
#   'opening': '$15,853,6463,838\n            theaters',
#   'budget': '$90,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 25 min',
#   'genres': 'Adventure, Animation, Comedy, Family, Fantasy',
#   'gross_dom': '$45,216,793',
#   'gross_inter': '$74,342,317',
#   'gross_world': '$119,559,110'},
#  {'title': 'Rambo: Last Blood',
#   'desc': 'Rambo must confront his past and unearth his ruthless combat skills to exact revenge in a final mission.',
#   'distr': 'LionsgateSee full company information\n\n',
#   'opening': '$18,872,9193,618\n            theaters',
#   'budget': '$50,000,000',
#   'mpaa': 'R',
#   'runtime': '1 hr 29 min',
#   'genres': 'Action, Thriller',
#   'gross_dom': '$44,819,352',
#   'gross_inter': '$46,671,001',
#   'gross_world': '$91,490,353'},
#  {'title': 'Playing with Fire',
#   'desc': 'A crew of rugged firefighters meet their match when attempting to rescue three rambunctious kids.',
#   'distr': 'Paramount PicturesSee full company information\n\n',
#   'opening': '$12,723,7813,125\n            theaters',
#   'budget': '$29,900,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 36 min',
#   'genres': 'Comedy, Family',
#   'gross_dom': '$44,451,847',
#   'gross_inter': '$24,179,822',
#   'gross_world': '$68,631,669'},
#  {'title': 'Harriet',
#   'desc': "The extraordinary tale of Harriet Tubman's escape from slavery and transformation into one of America's greatest heroes, whose courage, ingenuity, and tenacity freed hundreds of slaves and changed the course of history.",
#   'distr': 'Focus FeaturesSee full company information\n\n',
#   'opening': '$11,676,7202,059\n            theaters',
#   'budget': '$17,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 5 min',
#   'genres': 'Action, Biography, Drama, History',
#   'gross_dom': '$43,082,155',
#   'gross_inter': '$264,862',
#   'gross_world': '$43,347,017'},
#  {'title': "A Dog's Way Home",
#   'desc': 'A female dog travels four hundred miles in search of her owner throughout a Colorado wilderness.',
#   'distr': 'Sony Pictures Entertainment (SPE)See full company information\n\n',
#   'opening': '$11,251,2633,090\n            theaters',
#   'budget': '$18,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 36 min',
#   'genres': 'Adventure, Drama, Family',
#   'gross_dom': '$42,004,346',
#   'gross_inter': '$38,703,788',
#   'gross_world': '$80,708,134'},
#  {'title': 'The Angry Birds Movie 2',
#   'desc': 'The flightless birds and scheming green pigs take their feud to the next level.',
#   'distr': 'Sony Pictures Entertainment (SPE)See full company information\n\n',
#   'opening': '$10,354,0733,869\n            theaters',
#   'budget': '$65,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 37 min',
#   'genres': 'Adventure, Animation, Comedy, Family',
#   'gross_dom': '$41,667,116',
#   'gross_inter': '$106,124,931',
#   'gross_world': '$147,792,047'},
#  {'title': 'Little',
#   'desc': 'A woman is transformed into her younger self at a point in her life when the pressures of adulthood become too much to bear.',
#   'distr': 'Universal PicturesSee full company information\n\n',
#   'opening': '$15,405,4552,667\n            theaters',
#   'budget': '$20,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 49 min',
#   'genres': 'Comedy, Fantasy, Romance',
#   'gross_dom': '$40,860,481',
#   'gross_inter': '$8,126,615',
#   'gross_world': '$48,987,096'},
#  {'title': 'Queen & Slim',
#   'desc': "A couple's first date takes an unexpected turn when a police officer pulls them over.",
#   'distr': 'Universal PicturesSee full company information\n\n',
#   'opening': '$11,890,4901,690\n            theaters',
#   'budget': '$18,000,000',
#   'mpaa': 'R',
#   'runtime': '2 hr 12 min',
#   'genres': 'Crime, Drama, Romance',
#   'gross_dom': '$43,808,310',
#   'gross_inter': '$3,991,881',
#   'gross_world': '$47,800,191'},
#  {'title': 'Breakthrough',
#   'desc': 'When her 14-year-old son drowns in a lake, a faithful mother prays for him to come back from the brink of death and be healed.',
#   'distr': 'Twentieth Century FoxSee full company information\n\n',
#   'opening': '$11,282,3332,824\n            theaters',
#   'budget': '$14,000,000',
#   'mpaa': 'PG',
#   'runtime': '1 hr 56 min',
#   'genres': 'Biography, Drama',
#   'gross_dom': '$40,713,082',
#   'gross_inter': '$9,731,276',
#   'gross_world': '$50,444,358'},
#  {'title': 'The Mule',
#   'desc': 'A ninety-year-old horticulturist and Korean War veteran turns drug mule for a Mexican cartel.',
#   'distr': 'Warner Bros.See full company information\n\n',
#   'opening': '$17,509,4312,588\n            theaters',
#   'budget': '$50,000,000',
#   'mpaa': 'R',
#   'runtime': '1 hr 56 min',
#   'genres': 'Crime, Drama, Thriller',
#   'gross_dom': '$103,804,407',
#   'gross_inter': '$71,000,000',
#   'gross_world': '$174,804,407'},
#  {'title': 'Crawl',
#   'desc': 'A young woman, while attempting to save her father during a category 5 hurricane, finds herself trapped in a flooding house and must fight for her life against alligators.',
#   'distr': 'Paramount PicturesSee full company information\n\n',
#   'opening': '$12,005,2103,170\n            theaters',
#   'budget': '$13,500,000',
#   'mpaa': 'R',
#   'runtime': '1 hr 27 min',
#   'genres': 'Action, Drama, Horror, Sci-Fi, Thriller',
#   'gross_dom': '$39,014,193',
#   'gross_inter': '$52,527,904',
#   'gross_world': '$91,542,097'},
#  {'title': 'Little Women',
#   'desc': 'Jo March reflects back and forth on her life, telling the beloved story of the March sisters - four young women, each determined to live life on her own terms.',
#   'distr': 'Sony Pictures Entertainment (SPE)See full company information\n\n',
#   'opening': '$16,755,3103,308\n            theaters',
#   'budget': '$40,000,000',
#   'mpaa': 'PG',
#   'runtime': '2 hr 15 min',
#   'genres': 'Drama, Romance',
#   'gross_dom': '$108,101,214',
#   'gross_inter': '$108,500,000',
#   'gross_world': '$216,601,214'},
#  {'title': 'The Intruder',
#   'desc': 'A young married couple buys a beautiful house on several acres of land, only to find out that the man they bought it from refuses to let go of the property.',
#   'distr': 'Screen GemsSee full company information\n\n',
#   'opening': '$10,855,0542,222\n            theaters',
# ...
#  {'title': 'Ratchet & Clank',
#   'desc': 'When the galaxy comes under the threat of a nefarious space captain, a mechanic and his newfound robot ally join an elite squad of combatants to save the universe.',
#   'distr': 'Focus FeaturesSee full company information\n\n',
#   'opening': '$4,869,2782,891\n            theaters',
#   'budget': None,
#   'mpaa': 'PG',
#   'runtime': '1 hr 34 min',
#   'genres': 'Action, Adventure, Animation, Comedy, Family, Fantasy, Sci-Fi',
#   'gross_dom': '$8,821,329',
#   'gross_inter': '$4,564,408',
#   'gross_world': '$13,385,737'},
#  {'title': 'The Lobster',
#   'desc': 'In a dystopian near future, single people, according to the laws of The City, are taken to The Hotel, where they are obliged to find a romantic partner in forty-five days or are transformed into beasts and sent off into The Woods.',
#   'distr': 'A24See full company information\n\n',
#   'opening': '$190,2524\n            theaters',
#   'budget': None,
#   'mpaa': 'R',
#   'runtime': '1 hr 59 min',
#   'genres': 'Comedy, Drama, Romance, Sci-Fi, Thriller',
#   'gross_dom': '$8,700,374',
#   'gross_inter': '$251,977',
#   'gross_world': '$8,952,351'},
#  {'title': 'The Wild Life',
#   'desc': 'A daring parrot recounts how Robinson Crusoe came to be stranded on a tropical island.',
#   'distr': 'LionsgateSee full company information\n\n',
#   'opening': '$3,342,6962,493\n            theaters',
#   'budget': None,
#   'mpaa': 'PG',
#   'runtime': '1 hr 31 min',
#   'genres': 'Adventure, Animation, Comedy, Family',
#   'gross_dom': '$8,005,586',
#   'gross_inter': '$32,069,860',
#   'gross_world': '$40,075,446'},
#  {'title': 'Loving',
#   'desc': "The story of Richard and Mildred Loving, a couple whose arrest for interracial marriage in 1960s Virginia began a legal battle that would end with the Supreme Court's historic 1967 decision.",
#   'distr': 'Focus FeaturesSee full company information\n\n',
#   'opening': '$159,6154\n            theaters',
#   'budget': None,
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 3 min',
#   'genres': 'Biography, Drama, Romance',
#   'gross_dom': '$7,751,969',
#   'gross_inter': '$5,205,296',
#   'gross_world': '$12,957,265'},
#  {'title': 'Shut In',
#   'desc': 'A widowed child psychologist lives an isolated existence in rural New England. Caught in a deadly winter storm, she must find a way to rescue a young boy before he disappears forever.',
#   'distr': 'EuropaCorpSee full company information\n\n',
#   'opening': '$3,613,5672,058\n            theaters',
#   'budget': None,
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 31 min',
#   'genres': 'Drama, Horror, Mystery, Thriller',
#   'gross_dom': '$6,900,335',
#   'gross_inter': '$6,181,736',
#   'gross_world': '$13,082,071'},
#  {'title': 'The Brothers Grimsby',
#   'desc': 'A new assignment forces a top spy to team up with his football hooligan brother.',
#   'distr': 'Sony Pictures Entertainment (SPE)See full company information\n\n',
#   'opening': '$3,258,3272,235\n            theaters',
#   'budget': None,
#   'mpaa': 'R',
#   'runtime': '1 hr 23 min',
#   'genres': 'Action, Adventure, Comedy, Crime, Thriller',
#   'gross_dom': '$6,874,837',
#   'gross_inter': '$21,104,203',
#   'gross_world': '$27,979,040'},
#  {'title': 'The Danish Girl',
#   'desc': "A fictitious love story loosely inspired by the lives of Danish artists Lili Elbe and Gerda Wegener. Lili and Gerda's marriage and work evolve as they navigate Lili's groundbreaking journey as a transgender pioneer.",
#   'distr': 'Focus FeaturesSee full company information\n\n',
#   'opening': '$187,3184\n            theaters',
#   'budget': None,
#   'mpaa': 'R',
#   'runtime': '1 hr 59 min',
#   'genres': 'Biography, Drama, Romance',
#   'gross_dom': '$11,114,018',
#   'gross_inter': '$53,077,505',
#   'gross_world': '$64,191,523'},
#  {'title': 'The Young Messiah',
#   'desc': 'Tells the story of Jesus Christ at age seven as he and his family depart Egypt to return home to Nazareth. Told from his childhood perspective, it follows young Jesus as he grows into his religious identity.',
#   'distr': 'Focus FeaturesSee full company information\n\n',
#   'opening': '$3,294,8761,761\n            theaters',
#   'budget': None,
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 51 min',
#   'genres': 'Drama, Fantasy',
#   'gross_dom': '$6,490,401',
#   'gross_inter': '$839,937',
#   'gross_world': '$7,330,338'},
#  {'title': 'Jackie',
#   'desc': "Following the assassination of President John F. Kennedy, First Lady Jacqueline Kennedy fights through grief and trauma to regain her faith, console her children, and define her husband's historic legacy.",
#   'distr': 'Fox Searchlight PicturesSee full company information\n\n',
#   'opening': '$278,7155\n            theaters',
#   'budget': None,
#   'mpaa': 'R',
#   'runtime': '1 hr 40 min',
#   'genres': 'Biography, Drama, History',
#   'gross_dom': '$13,960,394',
#   'gross_inter': '$10,310,005',
#   'gross_world': '$24,270,399'},
#  {'title': 'Southside with You',
#   'desc': "Chronicles the 1989 summer afternoon when the future President of the United States, Barack Obama, wooed his future First Lady, Michelle Obama, on a first date across Chicago's South Side.",
#   'distr': 'Roadside AttractionsSee full company information\n\n',
#   'opening': '$2,868,403813\n            theaters',
#   'budget': None,
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 24 min',
#   'genres': 'Biography, Drama, History, Romance',
#   'gross_dom': '$6,304,223',
#   'gross_inter': '$324,380',
#   'gross_world': '$6,628,603'},
#  {'title': 'Captain Fantastic',
#   'desc': 'In the forests of the Pacific Northwest, a father devoted to raising his six kids with a rigorous physical and intellectual education is forced to leave his paradise and enter the world, challenging his idea of what it means to be a parent.',
#   'distr': 'Bleecker Street MediaSee full company information\n\n',
#   'opening': '$93,8244\n            theaters',
#   'budget': None,
#   'mpaa': 'R',
#   'runtime': '1 hr 58 min',
#   'genres': 'Comedy, Drama',
#   'gross_dom': '$5,879,835',
#   'gross_inter': '$16,907,691',
#   'gross_world': '$22,787,526'},
#  {'title': 'Lion',
#   'desc': 'A five-year-old Indian boy is adopted by an Australian couple after getting lost hundreds of kilometers from home. 25 years later, he sets out to find his lost family.',
#   'distr': 'The Weinstein CompanySee full company information\n\n',
#   'opening': '$123,3604\n            theaters',
#   'budget': '$12,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 58 min',
#   'genres': 'Biography, Drama',
#   'gross_dom': '$51,738,905',
#   'gross_inter': '$88,574,023',
#   'gross_world': '$140,312,928'},
#  {'title': 'Bleed for This',
#   'desc': "The inspirational story of World Champion Boxer Vinny Pazienza who, after a near fatal car crash which left him not knowing if he'd ever walk again, made one of sport's most incredible comebacks.",
#   'distr': 'Open Road Films (II)See full company information\n\n',
#   'opening': '',
#   'budget': '$6,000,000',
#   'mpaa': 'R',
#   'runtime': '1 hr 57 min',
#   'genres': 'Biography, Drama, Sport',
#   'gross_dom': '$5,083,906',
#   'gross_inter': '$1,614,773',
#   'gross_world': '$6,698,679'},
#  {'title': 'Incarnate',
#   'desc': 'A scientist with the ability to enter the subconscious minds of the possessed must save a young boy from the grips of a demon with powers never seen before, while facing the horrors of his past.',
#   'distr': 'BH TiltSee full company information\n\n',
#   'opening': '$2,534,8841,737\n            theaters',
#   'budget': '$5,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 27 min',
#   'genres': 'Horror, Thriller',
#   'gross_dom': '$4,799,774',
#   'gross_inter': '$4,237,284',
#   'gross_world': '$9,037,058'},
#  {'title': 'Hands of Stone',
#   'desc': "The legendary Roberto Duran and his equally legendary trainer Ray Arcel change each other's lives.",
#   'distr': 'The Weinstein CompanySee full company information\n\n',
#   'opening': '$1,751,388810\n            theaters',
#   'budget': None,
#   'mpaa': 'R',
#   'runtime': '1 hr 51 min',
#   'genres': 'Biography, Drama, Sport',
#   'gross_dom': '$4,712,792',
#   'gross_inter': '$265,561',
#   'gross_world': '$4,978,353'},
#  {'title': 'A Hologram for the King',
#   'desc': "A failed American sales rep looks to recoup his losses by traveling to Saudi Arabia and selling his company's product to a wealthy monarch.",
#   'distr': 'Roadside AttractionsSee full company information\n\n',
#   'opening': '$1,138,578401\n            theaters',
#   'budget': None,
#   'mpaa': 'R',
#   'runtime': '1 hr 38 min',
#   'genres': 'Comedy, Drama, Romance',
#   'gross_dom': '$4,212,494',
#   'gross_inter': '$4,957,013',
#   'gross_world': '$9,169,507'},
#  {'title': 'Swiss Army Man',
#   'desc': 'A hopeless man stranded on a deserted island befriends a dead body and together they go on a surreal journey to get home.',
#   'distr': 'A24See full company information\n\n',
#   'opening': '$105,4533\n            theaters',
#   'budget': None,
#   'mpaa': 'R',
#   'runtime': '1 hr 37 min',
#   'genres': 'Comedy, Drama, Fantasy, Romance',
#   'gross_dom': '$4,210,454',
#   'gross_inter': '$725,047',
#   'gross_world': '$4,935,501'},
#  {'title': 'Denial',
#   'desc': 'Acclaimed writer and historian Deborah E. Lipstadt must battle for historical truth to prove the Holocaust actually occurred when David Irving, a renowned denier, sues her for libel.',
#   'distr': 'Bleecker Street MediaSee full company information\n\n',
#   'opening': '$93,7285\n            theaters',
#   'budget': None,
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 49 min',
#   'genres': 'Biography, Drama',
#   'gross_dom': '$4,073,489',
#   'gross_inter': '$3,921,038',
#   'gross_world': '$7,994,527'},
#  {'title': 'Morgan',
#   'desc': 'A corporate risk-management consultant must decide whether or not to terminate an artificially created humanoid being.',
#   'distr': 'Twentieth Century FoxSee full company information\n\n',
#   'opening': '$2,012,7092,020\n            theaters',
#   'budget': '$8,000,000',
#   'mpaa': 'R',
#   'runtime': '1 hr 32 min',
#   'genres': 'Action, Horror, Sci-Fi, Thriller',
#   'gross_dom': '$3,915,251',
#   'gross_inter': '$4,894,156',
#   'gross_world': '$8,809,407'},
#  {'title': 'Max Steel',
#   'desc': 'The adventures of teenager Max McGrath and his alien companion, Steel, who must harness and combine their tremendous new powers to evolve into the turbo-charged superhero Max Steel.',
#   'distr': 'Open Road Films (II)See full company information\n\n',
#   'opening': '',
#   'budget': None,
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 32 min',
#   'genres': 'Action, Adventure, Fantasy, Sci-Fi',
#   'gross_dom': '$3,818,664',
#   'gross_inter': '$2,453,739',
#   'gross_world': '$6,272,403'},
#  {'title': 'Batman: The Killing Joke',
#   'desc': 'As Batman hunts for the escaped Joker, the Clown Prince of Crime attacks the Gordon family to prove a diabolical point mirroring his own fall into madness.',
#   'distr': 'Fathom EventsSee full company information\n\n',
#   'opening': None,
#   'budget': None,
#   'mpaa': 'R',
#   'runtime': '1 hr 16 min',
#   'genres': 'Action, Animation, Crime, Drama, Thriller',
#   'gross_dom': '$3,775,000',
#   'gross_inter': '$687,034',
#   'gross_world': '$4,462,034'},
#  {'title': 'Midnight Special',
#   'desc': "A father and son go on the run, pursued by the government and a cult drawn to the child's special powers.",
#   'distr': 'Warner Bros.See full company information\n\n',
#   'opening': '$190,0125\n            theaters',
#   'budget': None,
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 52 min',
#   'genres': 'Drama, Mystery, Sci-Fi, Thriller',
#   'gross_dom': '$3,712,282',
#   'gross_inter': '$3,028,365',
#   'gross_world': '$6,740,647'},
#  {'title': 'Anomalisa',
#   'desc': 'A man crippled by the mundanity of his life experiences something out of the ordinary.',
#   'distr': 'Paramount PicturesSee full company information\n\n',
#   'opening': '$135,2224\n            theaters',
#   'budget': '$8,000,000',
#   'mpaa': 'R',
#   'runtime': '1 hr 30 min',
#   'genres': 'Animation, Comedy, Drama, Romance',
#   'gross_dom': '$3,759,286',
#   'gross_inter': '$1,900,000',
#   'gross_world': '$5,659,286'},
#  {'title': "Rules Don't Apply",
#   'desc': 'The unconventional love story of an aspiring actress, her ambitious driver, and their eccentric boss, the legendary billionaire Howard Hughes.',
#   'distr': 'Twentieth Century FoxSee full company information\n\n',
#   'opening': '$1,589,6252,382\n            theaters',
#   'budget': '$25,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 7 min',
#   'genres': 'Comedy, Drama, Romance',
#   'gross_dom': '$3,652,206',
#   'gross_inter': '$233,136',
#   'gross_world': '$3,885,342'},
#  {'title': 'Miss Sloane',
#   'desc': 'In the high-stakes world of political power-brokers, Elizabeth Sloane is the most sought after and formidable lobbyist in D.C. But when taking on the most powerful opponent of her career, she finds winning may come at too high a price.',
#   'distr': 'EuropaCorpSee full company information\n\n',
#   'opening': '$59,7973\n            theaters',
#   'budget': None,
#   'mpaa': 'R',
#   'runtime': '2 hr 12 min',
#   'genres': 'Drama, Thriller',
#   'gross_dom': '$3,500,605',
#   'gross_inter': '$5,600,941',
#   'gross_world': '$9,101,546'},
#  {'title': 'Sing Street',
#   'desc': 'A boy growing up in Dublin during the 1980s escapes his strained family life by starting a band to impress the mysterious girl he likes.',
#   'distr': 'The Weinstein CompanySee full company information\n\n',
#   'opening': '$63,5735\n            theaters',
#   'budget': None,
#   'mpaa': 'PG-13',
#   'runtime': '1 hr 46 min',
#   'genres': 'Comedy, Drama, Music, Romance',
#   'gross_dom': '$3,237,118',
#   'gross_inter': '$10,387,404',
#   'gross_world': '$13,624,522'},
#  {'title': 'Green Room',
#   'desc': 'A punk rock band is forced to fight for survival after witnessing a murder at a neo-Nazi skinhead bar.',
#   'distr': 'A24See full company information\n\n',
#   'opening': '$87,9843\n            theaters',
#   'budget': None,
#   'mpaa': 'R',
#   'runtime': '1 hr 35 min',
#   'genres': 'Horror, Music, Thriller',
#   'gross_dom': '$3,220,371',
#   'gross_inter': '$548,843',
#   'gross_world': '$3,769,214'},
#  {'title': 'The Martian',
#   'desc': 'An astronaut becomes stranded on Mars after his team assume him dead, and must rely on his ingenuity to find a way to signal to Earth that he is alive.',
#   'distr': 'Twentieth Century FoxSee full company information\n\n',
#   'opening': '$54,308,5753,831\n            theaters',
#   'budget': '$108,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 24 min',
#   'genres': 'Adventure, Drama, Sci-Fi',
#   'gross_dom': '$228,433,663',
#   'gross_inter': '$401,728,227',
#   'gross_world': '$630,161,890'},
#  {'title': 'The Other Side of the Door',
#   'desc': 'After her young son is killed in a tragic accident, a woman learns of a ritual which will bring him back to say goodbye, but when she disobeys a sacred warning, she upsets the balance between life and death.',
#   'distr': 'Twentieth Century FoxSee full company information\n\n',
#   'opening': '$1,211,210546\n            theaters',
#   'budget': None,
#   'mpaa': 'R',
#   'runtime': '1 hr 36 min',
#   'genres': 'Horror',
#   'gross_dom': '$3,000,342',
#   'gross_inter': '$11,332,125',
#   'gross_world': '$14,332,467'},
#  {'title': 'Spectre',
#   'desc': "A cryptic message from James Bond's past sends him on a trail to uncover the existence of a sinister organisation named SPECTRE. With a new threat dawning, Bond learns the terrible truth about the author of all his pain in his most recent missions.",
#   'distr': 'Sony Pictures Entertainment (SPE)See full company information\n\n',
#   'opening': '$70,403,1483,929\n            theaters',
#   'budget': '$245,000,000',
#   'mpaa': 'PG-13',
#   'runtime': '2 hr 28 min',
#   'genres': 'Action, Adventure, Thriller',
#   'gross_dom': '$200,074,609',
#   'gross_inter': '$680,600,000',
#   'gross_world': '$880,674,609'},
#  {'title': 'Miles Ahead',
#   'desc': 'An exploration of the life and music of Miles Davis.',
#   'distr': 'Sony Pictures ClassicsSee full company information\n\n',
#   'opening': '$114,5304\n            theaters',
#   'budget': None,
#   'mpaa': 'R',
#   'runtime': '1 hr 40 min',
#   'genres': 'Biography, Drama, Music, Romance',
#   'gross_dom': '$2,610,896',
#   'gross_inter': '$863,062',
#   'gross_world': '$3,473,958'},
#  ...]

# %%
movie_stubs.head()
# Out:
#                                                     link_stub       release  \
# Avengers: Endgame  /release/rl3059975681/?ref_=bo_yld_table_1  Apr 26, 2019
# The Lion King      /release/rl3321923073/?ref_=bo_yld_table_2  Jul 19, 2019
# Toy Story 4        /release/rl3798500865/?ref_=bo_yld_table_3  Jun 21, 2019
# Frozen II          /release/rl2424210945/?ref_=bo_yld_table_4  Nov 22, 2019
# Captain Marvel     /release/rl3009644033/?ref_=bo_yld_table_5   Mar 8, 2019
#
#                   theaters
# Avengers: Endgame     4662
# The Lion King         4802
# Toy Story 4           4575
# Frozen II             4440
# Captain Marvel        4310

# %%
' '.join(test)
# Out:
# 'this is a test'

# %%
ls
# Out:
# Data_Scraping_Prototype.ipynb           cast_info_list_start_to_1500.pickle
# Data_Scraping_Prototype_Selenium.ipynb  clean_movie_df.pickle
# Feature Engineering.ipynb               cleaning_prototype.ipynb
# README.md                               geckodriver.log
# Regression prototype-V2.ipynb           movie_info.pickle
# Regression prototype.ipynb              movie_stubs.pickle
# Untitled.ipynb                          processed_movie_df.pickle
# cast_info.pickle                        usholidays.csv
# cast_info_list1500_to_end.pickle
