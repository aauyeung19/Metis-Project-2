# %%
import pickle
import pandas as pd
import numpy as np
import datetime as dt
import re

# %%
movie_df = pickle.load(open('clean_movie_df.pickle', 'rb'))

# %%
movie_df.Director()
# Out:
#               index                                    link_stub      release  \
# 1663       Sin City  /release/rl3027338753/?ref_=bo_yld_table_32  Apr 1, 2005
# 1704    Source Code  /release/rl4033906177/?ref_=bo_yld_table_60  Apr 1, 2011
# 961       Insidious  /release/rl3428550145/?ref_=bo_yld_table_63  Apr 1, 2011
# 881             Hop   /release/rl391874049/?ref_=bo_yld_table_25  Apr 1, 2011
# 2479  Woman in Gold   /release/rl981108225/?ref_=bo_yld_table_77  Apr 1, 2015
#
#       theaters                                               desc  \
# 1663      3230  A movie that explores the dark and miserable t...
# 1704      2971  A soldier wakes up in someone else's body and ...
# 961       2419  A family looks to prevent evil spirits from tr...
# 881       3616  E.B., the Easter Bunny's teenage son, heads to...
# 2479      2011  Maria Altmann, an octogenarian Jewish refugee,...
#
#                       distr   opening    budget   mpaa  runtime  ...  \
# ...
